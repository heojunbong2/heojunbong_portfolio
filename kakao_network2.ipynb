# %%
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Twitter
from konlpy.tag import Okt
from matplotlib import font_manager, rc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import networkx as nx

# %%
df_2019=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/kakao_datafile/frequency_data/frequency_y19.csv')
df_2019.head(5)
# Out:
#   word  freqeuncy  year
# 0   결제         26  2019
# 1   카드         17  2019
# 2   설치         15  2019
# 3   계좌         14  2019
# 4   인증         11  2019

# %%
g_2019 = nx.karate_club_graph()
g_2019 = nx.from_pandas_edgelist(df_2019, source = 'word', target = 'year')
pos = nx.spring_layout(g_2019, k = 0.1, iterations=200)

color_map_node = []
for node in g_2019:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2019, pos, node_size = 5000, node_color = color_map_node)
nx.draw_networkx_edges(g_2019, pos, width=1)
nx.draw_networkx_labels(g_2019, pos,  font_size=40, font_family='Malgun Gothic')
plt.show()

# %%
df_2020=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/kakao_datafile/frequency_data/frequency_y20.csv')
df_2020.head(5)
# Out:
#   word  freqeuncy  year
# 0   결제         71  2020
# 1   인증         53  2020
# 2   계좌         52  2020
# 3   카드         49  2020
# 4  로그인         45  2020

# %%
g_2020 = nx.karate_club_graph()
g_2020 = nx.from_pandas_edgelist(df_2020, source = 'word', target = 'year')
pos = nx.spring_layout(g_2020, k = 0.1, iterations=200)

color_map_node = []
for node in g_2020:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2020, pos, node_size = 5000, node_color = color_map_node)
nx.draw_networkx_edges(g_2020, pos, width=1)
nx.draw_networkx_labels(g_2020, pos,  font_size=40, font_family='Malgun Gothic')
plt.show()

# %%
df_2021=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/kakao_datafile/frequency_data/frequency_y21.csv')
df_2021.head(5)
# Out:
#    word  freqeuncy  year
# 0    결제         98  2021
# 1    계정         78  2021
# 2    소리         64  2021
# 3   로그인         60  2021
# 4  업데이트         59  2021

# %%
g_2021 = nx.karate_club_graph()
g_2021 = nx.from_pandas_edgelist(df_2021, source = 'word', target = 'year')
pos = nx.spring_layout(g_2021, k = 0.1, iterations=200)

color_map_node = []
for node in g_2021:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2021, pos, node_size = 5000, node_color = color_map_node)
nx.draw_networkx_edges(g_2021, pos, width=1)
nx.draw_networkx_labels(g_2021, pos,  font_size=40, font_family='Malgun Gothic')
plt.show()

# %%
df_2022=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/kakao_datafile/frequency_data/frequency_y22.csv')
df_2022.head(5)
# Out:
#    word  freqeuncy  year
# 0    인증         82  2022
# 1    결제         65  2022
# 2    주식         59  2022
# 3  업데이트         50  2022
# 4   로그인         48  2022

# %%
g_2022 = nx.karate_club_graph()
g_2022 = nx.from_pandas_edgelist(df_2022, source = 'word', target = 'year')
pos = nx.spring_layout(g_2022, k = 0.1, iterations=200)

color_map_node = []
for node in g_2022:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2022, pos, node_size = 5000, node_color = color_map_node)
nx.draw_networkx_edges(g_2022, pos, width=1)
nx.draw_networkx_labels(g_2022, pos,  font_size=40, font_family='Malgun Gothic')
plt.show()

# %%
df_2023=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/kakao_datafile/frequency_data/frequency_y23.csv')
df_2023.head(5)
# Out:
#   word  freqeuncy  year
# 0   결제         49  2023
# 1   주식         48  2023
# 2   오류         39  2023
# 3   계정         36  2023
# 4   불편         34  2023

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   word       20 non-null     object
#  1   freqeuncy  20 non-null     int64
#  2   year       20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 612.0+ bytes

# %%
g_2023 = nx.karate_club_graph()
g_2023 = nx.from_pandas_edgelist(df_2023, source = 'word', target = 'year')
pos = nx.spring_layout(g_2023, k = 0.1, iterations=200)

color_map_node = []
for node in g_2023:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2023, pos, node_size = 5000, node_color = color_map_node)
nx.draw_networkx_edges(g_2023, pos, width=1)
nx.draw_networkx_labels(g_2023, pos,  font_size=40, font_family='Malgun Gothic')
plt.show()

# %%
whole_data=pd.concat([df_2019,df_2020,df_2021,df_2022,df_2023])
whole_data
# Out:
#    word  freqeuncy  year
# 0    결제         26  2019
# 1    카드         17  2019
# 2    설치         15  2019
# 3    계좌         14  2019
# 4    인증         11  2019
# ..  ...        ...   ...
# 15   연결         16  2023
# 16   짜증         16  2023
# 17   점검         16  2023
# 18   설정         16  2023
# 19   위젯         16  2023
#
# [100 rows x 3 columns]

# %%
g = nx.karate_club_graph()
g = nx.from_pandas_edgelist(whole_data, source = 'word', target = 'year')
pos = nx.spring_layout(g, k = 0.1, iterations=200)

color_map_node = []
for node in g:
  if node == 2019:
    color_map_node.append('blue')
  elif node == 2020:
    color_map_node.append('red')
  elif node == 2021:
    color_map_node.append('yellow')
  elif node == 2022:
    color_map_node.append('green')
  elif node == 2023:
    color_map_node.append('orange')
  else:
    color_map_node.append('white')

color_map_edge = []
for edges in g.edges():
    if 2019 in edges:
        color_map_edge.append('blue')
    if 2020 in edges:
        color_map_edge.append('red')
    if 2021 in edges:
        color_map_edge.append('yellow')
    if 2022 in edges:
        color_map_edge.append('green')
    if 2023 in edges:
        color_map_edge.append('orange')

plt.figure(figsize=(30, 30))

nx.draw_networkx_nodes(g, pos, node_size = 5000, node_color = color_map_node)
nx.draw_networkx_edges(g, pos, width=1, edge_color = color_map_edge)
nx.draw_networkx_labels(g, pos,  font_size=35, font_family='Malgun Gothic')

plt.show()

# %%
import networkx as nx
import pandas as pd

df= pd.DataFrame(whole_data)


# 그래프 생성

g= nx.from_pandas_edgelist(df, source='word', target='year')

# Betweenness Centrality 계산
betweenness_centrality = nx.betweenness_centrality(g)

# Betweenness Centrality를 데이터프레임으로 변환
df_centrality = pd.DataFrame(list(betweenness_centrality.items()), columns=['word', 'betweenness_centrality'])

# 결과 출력
print(df_centrality)
# Out:
#      word  betweenness_centrality
# 0      결제                0.037386
# 1    2019                0.242243
# 2      카드                0.037386
# 3      설치                0.002492
# 4      계좌                0.037386
# 5      인증                0.037386
# 6      연결                0.013772
# 7      송금                0.024304
# 8      충전                0.006306
# 9      계정                0.037386
# 10     등록                0.006306
# 11     문제                0.000000
# 12     탈퇴                0.002492
# 13     불편                0.037386
# 14    로그인                0.037386
# 15     위젯                0.002570
# 16   본인인증                0.006785
# 17     화면                0.007309
# 18     만원                0.000000
# 19     시간                0.002570
# 20     광고                0.000000
# 21   2020                0.205670
# 22     오류                0.022886
# 23     입력                0.000000
# 24     정보                0.000000
# 25     가입                0.001161
# ...

# %%
df_centrality.sort_values('betweenness_centrality',ascending=False)
# Out:
#      word  betweenness_centrality
# 34   2022                0.336037
# 1    2019                0.242243
# 30   2021                0.215449
# 44   2023                0.215094
# 21   2020                0.205670
# 0      결제                0.037386
# 13     불편                0.037386
# 2      카드                0.037386
# 4      계좌                0.037386
# 5      인증                0.037386
# 9      계정                0.037386
# 14    로그인                0.037386
# 7      송금                0.024304
# 22     오류                0.022886
# 6      연결                0.013772
# 32   업데이트                0.013336
# 17     화면                0.007309
# 16   본인인증                0.006785
# 10     등록                0.006306
# 8      충전                0.006306
# 29     설정                0.006057
# 36     증권                0.003907
# 35     주식                0.003907
# 19     시간                0.002570
# 15     위젯                0.002570
# 12     탈퇴                0.002492
# ...
