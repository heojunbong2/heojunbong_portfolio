# %%
import pandas as pd 

df=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/kakao_datafile/kakao_preprocessing_neg_2021_2023.csv')

df.head(5)
# Out:
#               날짜                                                 리뷰  별점  \
# 0   2021년 2월 21일  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요... +)디자인에 문제가 아니라 바코...   2
# 1  2021년 10월 30일  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플....   3
# 2   2021년 1월 26일  솔직히 다른 리워드같은 경우는 굉장히 이벤트도 많이하고 편리해서 좋은 평을 주고 싶...   1
# 3   2021년 5월 18일  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...   2
# 4    2021년 2월 9일  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요,,, 데이터도 쓰고 와이파...   1
#
#    month                                                리뷰1  \
# 0  2021년  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요 디자인에 문제가 아니라 바코드가 분에...
# 1  2021년  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플 ...
# 2  2021년  솔직히 다른 리워드같은 경우는 굉장히 이벤트도 많이하고 편리해서 좋은 평을 주고 싶...
# 3  2021년  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...
# 4  2021년  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요 데이터도 쓰고 와이파이도 ...
#
#                                                  리뷰2
# 0  ['위젯', '짤려', '디자인', '문제', '바코드', '이나', '짤려', '...
# 1  ['국내', '모든', '금융', '관련', '어플', '비밀번호', '등록', '...
# 2  ['솔직', '워드', '이벤트', '이하', '편리', '미니', '금고', '서...
# 3  ['결제', '카드', '선택', '시간', '지나', '화면', '화면', '카드...
# 4  ['신규', '연결상태', '데이터', '와이파이', '데이터', '접속', '당장...

# %%
df.loc[df['month'] == '2021년', 'month'] = '2021'
df.loc[df['month'] == '2022년', 'month'] = '2022'
df.loc[df['month'] == '2023년', 'month'] = '2023'

# %%
import numpy as np
np.unique(df['month'])
# Out:
# array(['2021', '2022', '2023'], dtype=object)

# %%
import pandas as pd
from datetime import datetime


# Define a function to convert Korean month names to numeric format
def convert_month(korean_month):
    # Convert Korean month to English month
    english_month = datetime.strptime(korean_month, '%Y년 %m월 %d일').strftime('%Y-%m')
    return english_month

# Apply the function to the 'month' column
df['month'] = df['날짜'].apply(convert_month)

# Print the modified DataFrame
df.head(5)
# Out:
#               날짜                                                 리뷰  별점  \
# 0   2021년 2월 21일  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요... +)디자인에 문제가 아니라 바코...   2
# 1  2021년 10월 30일  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플....   3
# 2   2021년 1월 26일  솔직히 다른 리워드같은 경우는 굉장히 이벤트도 많이하고 편리해서 좋은 평을 주고 싶...   1
# 3   2021년 5월 18일  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...   2
# 4    2021년 2월 9일  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요,,, 데이터도 쓰고 와이파...   1
#
#      month                                                리뷰1  \
# 0  2021-02  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요 디자인에 문제가 아니라 바코드가 분에...
# 1  2021-10  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플 ...
# 2  2021-01  솔직히 다른 리워드같은 경우는 굉장히 이벤트도 많이하고 편리해서 좋은 평을 주고 싶...
# 3  2021-05  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...
# 4  2021-02  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요 데이터도 쓰고 와이파이도 ...
#
#                                                  리뷰2
# 0  ['위젯', '짤려', '디자인', '문제', '바코드', '이나', '짤려', '...
# 1  ['국내', '모든', '금융', '관련', '어플', '비밀번호', '등록', '...
# 2  ['솔직', '워드', '이벤트', '이하', '편리', '미니', '금고', '서...
# 3  ['결제', '카드', '선택', '시간', '지나', '화면', '화면', '카드...
# 4  ['신규', '연결상태', '데이터', '와이파이', '데이터', '접속', '당장...

# %%
df=df[df['month']!='2021-01']
df.head(5)
# Out:
#               날짜                                                 리뷰  별점  \
# 0   2021년 2월 21일  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요... +)디자인에 문제가 아니라 바코...   2
# 1  2021년 10월 30일  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플....   3
# 3   2021년 5월 18일  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...   2
# 4    2021년 2월 9일  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요,,, 데이터도 쓰고 와이파...   1
# 5   2021년 2월 10일  위젯이 기존 모양이 아닌 갑자기 작아져서 나옵니다. 짤려서 나오구요. 여러가지 모양...   1
#
#      month                                                리뷰1  \
# 0  2021-02  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요 디자인에 문제가 아니라 바코드가 분에...
# 1  2021-10  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플 ...
# 3  2021-05  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...
# 4  2021-02  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요 데이터도 쓰고 와이파이도 ...
# 5  2021-02  위젯이 기존 모양이 아닌 갑자기 작아져서 나옵니다 짤려서 나오구요 여러가지 모양 있...
#
#                                                  리뷰2
# 0  ['위젯', '짤려', '디자인', '문제', '바코드', '이나', '짤려', '...
# 1  ['국내', '모든', '금융', '관련', '어플', '비밀번호', '등록', '...
# 3  ['결제', '카드', '선택', '시간', '지나', '화면', '화면', '카드...
# 4  ['신규', '연결상태', '데이터', '와이파이', '데이터', '접속', '당장...
# 5  ['위젯', '기존', '모양', '짤려', '오구', '여러가지', '모양', '...

# %%
np.unique(df['month'])
# Out:
# array(['2021-02', '2021-03', '2021-04', '2021-05', '2021-06', '2021-07',
#        '2021-08', '2021-09', '2021-10', '2021-11', '2021-12', '2022-01',
#        '2022-02', '2022-03', '2022-04', '2022-05', '2022-06', '2022-07',
#        '2022-08', '2022-09', '2022-10', '2022-11', '2022-12', '2023-01',
#        '2023-02', '2023-03', '2023-04', '2023-05', '2023-06', '2023-07',
#        '2023-08', '2023-09', '2023-10'], dtype=object)

# %%
import pandas as pd


# Convert the 'date' column to a datetime object
df['month'] = pd.to_datetime(df['month'])

# Define bins for quarters
bins = pd.to_datetime(['2021-02-01', '2021-05-01', '2021-08-01', '2021-11-01', '2022-02-01',
                       '2022-05-01', '2022-08-01', '2022-11-01', '2023-02-01',
                       '2023-05-01', '2023-08-01'])

# Create a new column 'quarters' based on the specified criteria
df['quarters'] = pd.cut(pd.to_datetime(df['month']), bins=bins, labels=['2021-02~2021-04', '2021-05~2021-07', '2021-08~2021-10', '2021-11~2022-01',
                                                                         '2022-02~2022-04', '2022-05~2022-07', '2022-08~2022-10', '2022-11~2023-01',
                                                                         '2023-02~2023-04', '2023-05~2023-07'], right=False)

df
# Out:
#                  날짜                                                 리뷰  별점  \
# 0      2021년 2월 21일  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요... +)디자인에 문제가 아니라 바코...   2
# 1     2021년 10월 30일  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플....   3
# 3      2021년 5월 18일  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...   2
# 4       2021년 2월 9일  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요,,, 데이터도 쓰고 와이파...   1
# 5      2021년 2월 10일  위젯이 기존 모양이 아닌 갑자기 작아져서 나옵니다. 짤려서 나오구요. 여러가지 모양...   1
# ...             ...                                                ...  ..
# 1384   2023년 4월 12일                                  카카오페이 쉽게 탈하는법 없나요   1
# 1385   2023년 1월 12일                             미장 증권 개장했는데 나만 멈췄나여?ㅜㅠ   1
# 1386   2023년 3월 17일                                        충전하고 인출 오류남   1
# 1387   2023년 1월 20일                                      출석체크 왜 안되나요??   1
# 1388   2023년 9월 23일                                렉 걸리는거 절대 안고치네...ㄷㄷ   1
#
#           month                                                리뷰1  \
# 0    2021-02-01  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요 디자인에 문제가 아니라 바코드가 분에...
# 1    2021-10-01  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플 ...
# 3    2021-05-01  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...
# 4    2021-02-01  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요 데이터도 쓰고 와이파이도 ...
# 5    2021-02-01  위젯이 기존 모양이 아닌 갑자기 작아져서 나옵니다 짤려서 나오구요 여러가지 모양 있...
# ...         ...                                                ...
# 1384 2023-04-01                                  카카오페이 쉽게 탈하는법 없나요
# 1385 2023-01-01                                미장 증권 개장했는데 나만 멈췄나여
# 1386 2023-03-01                                        충전하고 인출 오류남
# 1387 2023-01-01                                        출석체크 왜 안되나요
# 1388 2023-09-01                                     렉 걸리는거 절대 안고치네
#
#                                                     리뷰2         quarters
# 0     ['위젯', '짤려', '디자인', '문제', '바코드', '이나', '짤려', '...  2021-02~2021-04
# 1     ['국내', '모든', '금융', '관련', '어플', '비밀번호', '등록', '...  2021-08~2021-10
# 3     ['결제', '카드', '선택', '시간', '지나', '화면', '화면', '카드...  2021-05~2021-07
# 4     ['신규', '연결상태', '데이터', '와이파이', '데이터', '접속', '당장...  2021-02~2021-04
# 5     ['위젯', '기존', '모양', '짤려', '오구', '여러가지', '모양', '...  2021-02~2021-04
# ...                                                 ...              ...
# 1384                                                 []  2023-02~2023-04
# 1385                                 ['미장', '증권', '개장']  2022-11~2023-01
# 1386                                       ['충전', '오류']  2023-02~2023-04
# 1387                                       ['출석', '체크']  2022-11~2023-01
# 1388                                  ['렉', '절대', '고치']              NaN
#
# [1357 rows x 7 columns]

# %%
# Convert the 'quarters' column to object type
df['quarters'] = df['quarters'].astype('object')
# Modify the specific value
df.loc[df['month'] == '2023-08-01', 'quarters'] = '2023-08~2023-10'
df.loc[df['month'] == '2023-09-01', 'quarters'] = '2023-08~2023-10'
df.loc[df['month'] == '2023-10-01', 'quarters'] = '2023-08~2023-10'

# %%
from sklearn.feature_extraction.text import CountVectorizer 
from konlpy.tag import Okt 
twit=Okt()

# %%
from konlpy.tag import Mecab
from tqdm import tqdm
import re
import pickle
import csv
import pandas as pd
from pandas import DataFrame 
import numpy as np

# %%
import ast

processed_data=[]
for i in range(len(df)):
    processed_data.append(ast.literal_eval(df['리뷰2'].iloc[i]))

# %%
processed_data
# Out:
# [['위젯',
#   '짤려',
#   '디자인',
#   '문제',
#   '바코드',
#   '이나',
#   '짤려',
#   '바탕화면',
#   '노트',
#   '이구',
#   '아마',
#   '업그레이드',
#   '문제',
#   '수정',
#   '고도',
#   '상황',
#   '인지',
#   '위젯',
#   '위젯',
#   '의미'],
#  ['국내',
#   '모든',
#   '금융',
#   '관련',
#   '어플',
#   '비밀번호',
#   '등록',
#   '가장',
#   '어플',
#   '보통',
#   '사용자',
#   '자기',
#   '쓰기',
#   '비번',
#   '일단',
#   '무조건',
#   '불가능',
#   '비번',
#   '시작',
#   '사용자',
#   '비번',
#   '본인',
#   '비번',
#   '요구',
#   '어플',
#   '그거'],
#  ['결제',
#   '카드',
#   '선택',
#   '시간',
#   '지나',
#   '화면',
#   '화면',
#   '카드',
#   '그대로',
#   '결제',
#   '현금',
#   '충전',
#   '짜증',
#   '카드',
#   '결제',
#   '불편',
#   '결제'],
#  ['신규', '연결상태', '데이터', '와이파이', '데이터', '접속', '당장', '말썽', '어뜨케'],
#  ['위젯',
#   '기존',
#   '모양',
#   '짤려',
#   '오구',
#   '여러가지',
#   '모양',
#   '바탕화면',
#   '치하',
#   '순간',
#   '아집',
#   '매크로',
#   '답변',
#   '노노',
#   '노트',
#   '사용자'],
#  ['유심',
#   '정보',
#   '인증',
#   '도구로',
#   '활용',
#   '기기',
#   '유심',
#   '동시',
#   '탑재',
#   '설치',
#   '인증',
#   '구조',
#   '기기',
#   '통화',
#   '유심',
#   '탑재',
#   '기기',
#   '불리',
#   '불가',
#   '이상',
#   '특이',
#   '상황',
#   '멀티',
#   '디바이',
#   '드림'],
#  ['증권',
#   '출금',
#   '방법',
#   '수가',
#   '상담',
#   '채팅',
#   '출금',
#   '방법',
#   '화가',
#   '출금',
#   '복잡',
#   '입출금',
#   '메인',
#   '화면',
#   '삽하',
#   '입금',
#   '출금',
#   '출금',
#   '답변',
#   '어이',
#   '쿡말'],
#  ['처음', '킬때', '띠링', '소리', '설정', '소리', '이어폰', '이어폰', '소리', '용한', '상황'],
#  ['연결',
#   '성공',
#   '계좌',
#   '카드',
#   '페이지',
#   '계좌',
#   '연결',
#   '페이지',
#   '이동',
#   '처럼',
#   '계좌',
#   '연결',
#   '인하',
#   '계좌연결',
#   '적금',
#   '통장',
#   '연결',
#   '조차'],
#  ['모바일',
#   '교통카드',
#   '농협',
#   '설치',
#   '어도',
#   '불가',
#   '교통카드',
#   '신청',
#   '단순',
#   '설치',
#   '어도',
#   '제해',
#   '야만',
#   '현재',
#   '농협',
#   '필요',
#   '마다',
#   '설치',
#   '매우',
#   '불편',
#   '원인',
#   '해결',
#   '부탁',
#   '드립'],
#  ['순간', '부터', '관리', '업데이트', '설치', '일전', '고정', '업데이트', '수동', '업데이트', '마저'],
#  ['설치',
#   '권한',
#   '등록부',
#   '허용',
#   '버튼',
#   '지지',
#   '다음',
#   '화면',
#   '갤럭시',
#   '종이',
#   '권한',
#   '등록',
#   '허용',
#   '등록',
#   '오류',
#   '수정',
#   '업데이트'],
#  ['인증',
#   '전화',
#   '등록',
#   '과정',
#   '오류',
#   '전화',
#   '상태',
#   '계좌',
#   '등록',
#   '오류',
#   '전화',
#   '인증',
#   '한국',
#   '유심',
#   '스팸',
#   '번호',
#   '설정',
#   '설마',
#   '국외',
#   '계좌',
#   '등록'],
#  ['어이',
#   '버킷리스트',
#   '안보',
#   '설정',
#   '증권',
#   '그것',
#   '불편',
#   '수도',
#   '최악',
#   '생각',
#   '수록',
#   '버튼',
#   '몇개'],
#  ['현재',
#   '고객',
#   '센터',
#   '연결',
#   '고시',
#   '도하',
#   '이나',
#   '좌절',
#   '고지',
#   '기전',
#   '만원',
#   '충전',
#   '만원',
#   '사라',
#   '충전',
#   '종종',
#   '실물',
#   '고객',
#   '센터',
#   '연결',
#   '난해',
#   '오기',
#   '은시',
#   '간이',
#   '이문',
#   '적하',
#   '해결',
#   '리뷰'],
#  ['미니',
#   '금고',
#   '투자',
#   '먹통',
#   '고객',
#   '센터',
#   '답변',
#   '공유',
#   '어플',
#   '통해',
#   '미노',
#   '사유',
#   '최근',
#   '버전',
#   '최신',
#   '버전',
#   '업데이트',
#   '웹뷰',
#   '오류로',
#   '기존',
#   '충돌',
#   '진입',
#   '실패',
#   '어플',
#   '통해',
#   '투자',
#   '서비스',
#   '원활',
#   '번거',
#   '로우',
#   '아래',
#   '방법',
#   '업데이트',
#   '부탁',
#   '드립',
#   '휴대폰',
#   '설정',
#   '어플리케이션',
#   '검색',
#   '선택',
#   '오른쪽',
#   '상단',
#   '업데이트',
#   '방법',
#   '설정',
#   '어플리케이션',
#   '검색',
#   '선택',
#   '오른쪽',
#   '상단',
#   '업데이트',
#   '이후',
#   '하단',
#   '중지',
#   '클릭'],
#  ['미니', '금고', '억만년', '며칠', '포기', '업데이트', '어찌', '이전', '버전', '복장', '짜증'],
#  ['영수증',
#   '낭패',
#   '모바일',
#   '영수증',
#   '마음대로',
#   '문자',
#   '고요',
#   '문자',
#   '연동',
#   '카드',
#   '정리',
#   '중이',
#   '었는데',
#   '보름',
#   '정도',
#   '비어',
#   '기하',
#   '문자',
#   '이상하',
#   '자동',
#   '등록',
#   '카드',
#   '문의',
#   '키톡',
#   '영수증',
#   '가입',
#   '전화',
#   '해지',
#   '제대로',
#   '보름치',
#   '일일이',
#   '수기',
#   '가계부',
#   '등록',
#   '시스템'],
#  ['알람',
#   '결제',
#   '카드',
#   '선호',
#   '카드',
#   '저장',
#   '여전',
#   '매번',
#   '우선',
#   '모자라',
#   '신용카드',
#   '결제',
#   '카드',
#   '할인',
#   '리셋',
#   '개선',
#   '요청',
#   '여전',
#   '사용자',
#   '입장',
#   '고려',
#   '신용카드',
#   '카드',
#   '디자인',
#   '안보',
#   '여주',
#   '단색',
#   '처리',
#   '카드',
#   '구분',
#   '오히려',
#   '톡앱',
#   '결제',
#   '메뉴',
#   '그나',
#   '사항',
#   '적용',
#   '부서',
#   '업무',
#   '공유',
#   '또한',
#   '전체',
#   '며뉴',
#   '나열',
#   '상단',
#   '분류',
#   '지원',
#   '좀더',
#   '접근',
#   '구성',
#   '우선',
#   '어도',
#   '분류',
#   '섹션',
#   '메뉴',
#   '글자',
#   '크게',
#   '표현'],
#  ['이번', '업뎃', '바코드', '제하', '시간', '초과', '종료', '시간', '초과', '정도', '종료', '수정'],
#  ['분명',
#   '입력',
#   '정보',
#   '입력',
#   '얼굴인식',
#   '결제',
#   '화면',
#   '오기',
#   '결제',
#   '덕분',
#   '페이지',
#   '가면',
#   '할인',
#   '할인',
#   '짜증',
#   '당하'],
#  ['평이',
#   '신경질',
#   '데이터',
#   '무시',
#   '데이터',
#   '네트워크',
#   '원활',
#   '와이파이',
#   '연결',
#   '연결',
#   '바로',
#   '바로',
#   '출근길'],
#  ['숫자',
#   '지질',
#   '거나',
#   '뭔가',
#   '빨간색',
#   '모든',
#   '메뉴',
#   '지질',
#   '쿠폰',
#   '강제',
#   '중국',
#   '알리페',
#   '정보',
#   '심지어',
#   '알림',
#   '는걸',
#   '설정',
#   '광고',
#   '문구',
#   '알림',
#   '쓰레기',
#   '지불',
#   '수단',
#   '수가'],
#  ['충전',
#   '가맹',
#   '무용지물',
#   '홈플러스',
#   '불가',
#   '이나',
#   '접근성',
#   '이나',
#   '방법',
#   '매우',
#   '리하',
#   '더욱',
#   '아쉬움'],
#  ['최악', '이상', '아이디', '가입', '고함', '인증', '노력', '니지'],
#  ['제발',
#   '시작',
#   '소리',
#   '빼주',
#   '소리',
#   '마다',
#   '스트레스',
#   '시작',
#   '소리',
#   '게임',
#   '게임',
#   '소리',
#   '설정',
#   '설정'],
#  ['어어',
#   '얼씬',
#   '불편',
#   '송금',
#   '무료',
#   '불편',
#   '혜택',
#   '점점',
#   '창렬',
#   '해지',
#   '불편',
#   '점점',
#   '구려'],
#  ['소리', '알림', '업데이트', '알림', '소리', '사람', '변경', '설정', '무례', '생각'],
#  ['주식', '계좌', '공동', '인증서', '등록증', '화면', '무한', '대기', '진행', '문제', '작년'],
#  ['계좌연결',
#   '제대로',
#   '적금',
#   '최근',
#   '만기',
#   '해지',
#   '연결',
#   '업데이트',
#   '마찬가지',
#   '미니',
#   '금고',
#   '버킷리스트',
#   '찾기',
#   '화면',
#   '바로가기',
#   '점점'],
#  ['업데이트', '이후', '바코드', '시간', '초과', '자주', '새로고침', '인식', '완전', '오기', '인식'],
#  ['인지',
#   '온라인',
#   '투자',
#   '조회',
#   '꽁꽁',
#   '노란색',
#   '동그라미',
#   '전체',
#   '온라인',
#   '투자',
#   '현황',
#   '조회',
#   '경로',
#   '수가',
#   '전화',
#   '상담',
#   '고생',
#   '이상',
#   '투자'],
#  ['시적',
#   '어플',
#   '오류',
#   '어플',
#   '설치',
#   '관리',
#   '업데이트',
#   '공동',
#   '인증서',
#   '등록',
#   '완료',
#   '업데이트',
#   '어플',
#   '업데이트',
#   '아직',
#   '계좌연결',
#   '등록',
#   '전혀'],
#  ['처음', '시작', '소리', '수도', '신경', '마다', '소리', '무음', '소리'],
#  ['어플',
#   '시작',
#   '소리',
#   '어플',
#   '미디어',
#   '소리',
#   '무음',
#   '무적',
#   '불편',
#   '수정',
#   '이름',
#   '황창환',
#   '이예',
#   '열심',
#   '시나'],
#  ['시작', '알림', '알림', '본인', '설정', '도록'],
#  ['계좌연결',
#   '제하',
#   '무조건',
#   '만원',
#   '출금',
#   '부족',
#   '계좌',
#   '이체',
#   '필요',
#   '금액',
#   '출금',
#   '필요',
#   '출금',
#   '지니',
#   '잔돈',
#   '마다',
#   '짜증'],
#  ['혜택',
#   '점점',
#   '불편',
#   '적립',
#   '한적',
#   '머리',
#   '혜택',
#   '이나',
#   '적립',
#   '적립',
#   '정도',
#   '다라',
#   '통해',
#   '다음',
#   '시즌',
#   '혜택'],
#  ['현재',
#   '군인',
#   '장병',
#   '보안',
#   '카메라',
#   '지면',
#   '자동',
#   '카메라',
#   '자동',
#   '전혀',
#   '송금',
#   '카메라',
#   '도록',
#   '시오'],
#  ['소리', '띠링', '소리', '강제', '적용', '앱킨다', '외치', '사용자', '불쾌감', '업데이트', '생각'],
#  ['실행', '띠링', '소리', '벨소리', '기준', '설정', '된거', '벨소리', '일수', '실행', '소리'],
#  ['인증', '하란', '주민등록번호', '제대로', '입력', '통신사', '제대로', '통신사', '정보'],
#  ['번호', '계정', '연결', '자동', '계정', '통장', '충전'],
#  ['교통카드',
#   '짜증',
#   '기존',
#   '교통카드',
#   '어플',
#   '수수료',
#   '환불',
#   '교통',
#   '삼성',
#   '아래',
#   '리뷰',
#   '진작',
#   '충전',
#   '상태',
#   '제대로',
#   '내용',
#   '공지',
#   '홍보',
#   '수수료',
#   '충전',
#   '충전',
#   '금액',
#   '불하',
#   '수수료',
#   '난하',
#   '돈버실',
#   '당일',
#   '충전',
#   '정도',
#   '수수료',
#   '기존',
#   '서도',
#   '수수료',
#   '이중',
#   '손해',
#   '손해',
#   '이용자',
#   '어찌',
#   '부족',
#   '정보',
#   '이용자',
#   '피해',
#   '홍보',
#   '려면',
#   '자세',
#   '내용',
#   '전달',
#   '기존',
#   '교통',
#   '어플',
#   '지우',
#   '제창',
#   '지하철',
#   '아이콘',
#   '바로',
#   '방법',
#   '홍보',
#   '팝업창',
#   '불편',
#   '손해',
#   '이용자',
#   '그동안',
#   '실망'],
#  ['배송', '중인', '버전', '업데이트', '연결', '기만', '지우', '설치', '업데이트', '정보', '최신'],
#  ['버스', '환승', '교통카드', '카드', '환승', '환승'],
#  ['관리', '화면', '업데이트', '버튼', '지나', '업데이트', '데이터', '보고', '최적화', '부탁'],
#  ['알리',
#   '워드',
#   '할인',
#   '쿠폰',
#   '뭔가',
#   '최근',
#   '워드',
#   '금액',
#   '처음',
#   '쿠폰',
#   '제하',
#   '답변',
#   '쿠폰',
#   '지급',
#   '워드',
#   '쿠폰',
#   '캐시',
#   '이나',
#   '포인트',
#   '지급',
#   '지급',
#   '수단'],
#  ['로그인', '로그인', '네트워크', '불안', '로그인', '결제'],
#  ['카드',
#   '수령',
#   '항상',
#   '기분',
#   '저번',
#   '잘못',
#   '이번',
#   '문자',
#   '다리',
#   '부재',
#   '중전',
#   '서비스',
#   '별로'],
#  ['위젯', '설정', '복창', '카드', '연결', '반복', '완료', '카드', '연결', '글자', '보임', '쓰레기'],
#  ['로그인', '려면', '인증', '새로운계정', '설정', '인증', '포기', '수차', '처음'],
#  ['관리', '업데이트', '마다', '환경', '밑바닥', '손절'],
#  ['로그인', '려면', '휴대폰', '인증', '휴대폰', '인증', '계정', '로그인', '무한', '반복', '포기'],
#  ['지갑', '쇼핑', '접속', '에러', '점검', '최근', '빈번', '한동', '실망'],
#  ['정보', '업데이트', '메뉴', '배치', '뭔가', '수선'],
#  ['개화',
#   '직장',
#   '회비',
#   '총무',
#   '통장',
#   '개인',
#   '통장',
#   '연동',
#   '카카',
#   '페로',
#   '결제',
#   '서로',
#   '구별',
#   '공유',
#   '덕분',
#   '직장',
#   '총무',
#   '로서',
#   '개인',
#   '충전',
#   '전부',
#   '차감',
#   '회비',
#   '통장',
#   '개인',
#   '통장',
#   '항상',
#   '해당',
#   '금액',
#   '도로',
#   '이체',
#   '수도',
#   '제대로',
#   '설명',
#   '부탁',
#   '드립',
#   '일단',
#   '방금',
#   '제하',
#   '자동',
#   '기존',
#   '차감',
#   '가금',
#   '충전',
#   '형식',
#   '었네',
#   '식이',
#   '카카'],
#  ['인식', '조차'],
#  ['수가', '표시', '보라', '일부러', '알림', '설정'],
#  ['실행', '종료', '나름', '금융', '테스트', '올리슈'],
#  ['얼마', '전부', '접속', '설치', '접속', '문제', '인지', '겔럭시'],
#  ['본인인증', '번호', '내면', '자동', '입력', '고요', '래서'],
#  ['그닥', '배달', '결제', '적립', '포인트'],
#  ['기존',
#   '관리',
#   '버킷리스트',
#   '미니',
#   '금고',
#   '사라',
#   '즐겨찾기',
#   '표시',
#   '나타',
#   '일일이',
#   '검색',
#   '가야'],
#  ['동하', '정보', '접속', '카드', '계좌', '연동', '저장'],
#  ['증권사', '연결', '공인', '인증서', '아이디', '간편', '연결', '언제', '최근', '해결'],
#  ['부분',
#   '자세',
#   '설명',
#   '알림',
#   '한시',
#   '익숙',
#   '불편',
#   '미니',
#   '금고',
#   '계좌',
#   '거래',
#   '적응',
#   '맘대로',
#   '사용자',
#   '배려'],
#  ['띠링',
#   '소리',
#   '개선',
#   '요청',
#   '답변',
#   '담당자',
#   '전달',
#   '언제',
#   '개발',
#   '사람',
#   '이하',
#   '시간',
#   '일도',
#   '어찌',
#   '사람',
#   '마다',
#   '깜짝',
#   '기도',
#   '짜증'],
#  ['어플',
#   '실행',
#   '소리',
#   '아이',
#   '실행',
#   '띠링',
#   '소리',
#   '미디어',
#   '음량',
#   '상관',
#   '어플',
#   '설정',
#   '짜증',
#   '칵퉤'],
#  ['충전', '고요', '사람', '계좌', '어쩌구저쩌구', '고요', '충전', '짜증', '임티', '솔직', '안치', '인증'],
#  ['결제',
#   '사이트',
#   '바로',
#   '연결',
#   '본계',
#   '가입',
#   '불가능',
#   '고해',
#   '계정',
#   '계정',
#   '로그인',
#   '수가',
#   '바로',
#   '연결',
#   '로그인',
#   '선택',
#   '수라도',
#   '부탁',
#   '드립'],
#  ['수록', '아지', '라가', '교통카드', '메뉴', '어디가', '박아', '수가'],
#  ['실행', '로고', '뜰때', '소리', '처음', '미디어', '소리', '음소거', '놨는데', '소리', '알림', '소리'],
#  ['모바일',
#   '교통카드',
#   '며칠',
#   '부터',
#   '부족',
#   '안내',
#   '겨우',
#   '어찌',
#   '승차',
#   '하차',
#   '승차',
#   '처리',
#   '라며',
#   '매번',
#   '짜증',
#   '교통카드',
#   '카드',
#   '모드',
#   '정상인',
#   '환불',
#   '원래',
#   '아가',
#   '불편'],
#  ['여전',
#   '정하나',
#   '계정',
#   '개인',
#   '사람',
#   '동시',
#   '불편',
#   '상관',
#   '인증',
#   '만하',
#   '연동',
#   '던데',
#   '개선'],
#  ['결제', '워드', '흰색', '대기', '화면', '갤럭시', '노트', '옛날', '기종은', '서비스', '제공', '제한'],
#  ['업뎃', '연결', '통장', '갠데', '주식', '몇개', '이상하'],
#  ['포인트', '사대', '불편', '처럼', '포인트'],
#  ['교통카드', '충전', '교통카드', '심지어', '교통카드', '해지', '상태', '겨우', '교통카드', '삼성', '짜증'],
#  ['실행', '효과음', '효과음', '불편'],
#  ['미사', '중인', '아이디', '비밀번호', '생각', '인증', '선불', '여서', '인증', '불가능'],
#  ['교통카드', '수정', '족하', '오류', '대여섯', '도하', '정상', '작동'],
#  ['카드',
#   '우리은행',
#   '체크카드',
#   '신용카드',
#   '등록',
#   '공동',
#   '인증서',
#   '인증',
#   '카드',
#   '등록',
#   '완료',
#   '정작',
#   '카드'],
#  ['실행', '중간', '광고', '우지', '바로', '코드', '스캔', '도록', '하자', '불편'],
#  ['오픈',
#   '소리',
#   '제거',
#   '아보',
#   '곳도',
#   '아래',
#   '에보니',
#   '불편',
#   '건의',
#   '여러',
#   '모처럼',
#   '제거',
#   '상태'],
#  ['투자', '먹통', '안보', '지우', '설치', '오류', '발생'],
#  ['업데이트', '가필', '바로', '연결', '업데이트', '이모티콘', '나이', '신분', '쓰시'],
#  ['휴면',
#   '계정',
#   '알람',
#   '접속',
#   '등록',
#   '본인인증',
#   '서류',
#   '기화',
#   '요청',
#   '서비스',
#   '해지',
#   '로그인',
#   '서비스',
#   '해지'],
#  ['비밀번호', '설정', '지문', '인식', '설정', '결제', '바코드', '띄우기', '사용자', '과정', '오류'],
#  ['이번', '업데이트', '이후', '지문', '모든', '기믕', '동하', '불편'],
#  ['업데이트', '위젯', '위아래', '수정', '갤럭시'],
#  ['로그인', '설정', '자세', '래서', '순식간', '은지', '인증번호', '수백'],
#  ['자동', '결제', '연결', '연결', '상태', '문구', '해결', '방법', '보이지', '거임'],
#  ['아이디', '경하', '기존', '탈퇴', '진행', '탈퇴', '탈퇴', '이기', '짜증'],
#  ['로딩', '출금', '짜증', '출금', '리해'],
#  ['비밀번호', '설정', '응답', '비밀번호', '자리', '입력', '전화', '입력', '화면', '초기', '전화', '기합'],
#  ['계좌',
#   '갱신',
#   '동안',
#   '어플',
#   '새로고침',
#   '그대로',
#   '가입',
#   '의문',
#   '모든',
#   '얼마',
#   '인지',
#   '지출',
#   '역도',
#   '동안',
#   '탈퇴',
#   '신청',
#   '하란'],
#  ['햅틱', '휴대폰', '설정'],
#  ['고객정보', '동의', '표시', '개인정보', '기분', '매우', '쁘네'],
#  ['오늘', '투자', '페이지', '어플', '강제', '종료'],
#  ['네트워크', '이틀', '로그인', '설치', '마찬가지'],
#  ['연결', '금융', '등록', '남아', '개화', '문제점', '이생', '기면', '문의', '메뉴', '어떡'],
#  ['시작', '소리', '소리', '음으로', '소리', '소리', '설정'],
#  ['번호',
#   '가입',
#   '명의',
#   '자가',
#   '계정',
#   '수가',
#   '계정',
#   '번호',
#   '인증',
#   '가입',
#   '계정',
#   '로그인',
#   '번호'],
#  ['디자인', '여러가지', '미니', '금고', '지고', '투자', '된거'],
#  ['처리', '은근', '처리', '아가'],
#  ['로그인', '시스템', '오류'],
#  ['교통카드', '충전', '위치', '무임', '승차'],
#  ['권한', '이하', '전화', '권한', '필요', '위치', '굳이', '요한', '그동안', '권한', '전화', '권한'],
#  ['교통카드', '필수', '체크', '부분', '교통카드', '진행'],
#  ['업뎃전', '업뎃후', '바코드', '유효', '시간', '결제', '새로고침', '변경', '업뎃되', '시래기'],
#  ['교통카드', '충전'],
#  ['위젯',
#   '설정',
#   '직관',
#   '이지',
#   '불편',
#   '중국',
#   '회사',
#   '알리페',
#   '워드',
#   '탈퇴',
#   '과정',
#   '불편',
#   '정보',
#   '중국',
#   '알리페',
#   '서버',
#   '확실',
#   '문제'],
#  ['어플', '특정', '럭키', '이나', '투자', '문제', '해결'],
#  ['개도', '오류', '발생', '잠시', '문구', '답답', '탈퇴', '송금', '서도', '이상'],
#  ['본인',
#   '명의',
#   '시대',
#   '역행',
#   '복잡',
#   '시스템',
#   '제발',
#   '바란',
#   '전화',
#   '직원',
#   '무조건',
#   '로봇',
#   '채팅',
#   '얼마나',
#   '버는데',
#   '소비자',
#   '불편',
#   '라라',
#   '업체',
#   '선물',
#   '보고',
#   '을지',
#   '혼자'],
#  ['투자', '투자', '항목', '보이지', '화면'],
#  ['실행', '동하', '소리', '방법', '설정', '소리', '설정', '접속', '마다'],
#  ['만하', '태블릿', '어플', '이나', '본인', '인증', '문자', '유심', '인증'],
#  ['실행', '소리', '생각', '업뎃한거임', '짜증'],
#  ['네트워크', '연결', '시간', '전하', '오류'],
#  ['명의', '변경', '요구', '서류', '보름', '지나', '신분증', '주소', '처리', '난하'],
#  ['기존', '가입', '정보', '이하', '불가', '본인인증', '정보', '도저히', '해답'],
#  ['전화번호', '메일', '입력', '입력', '가입', '먹통', '쓰기', '불편'],
#  ['포인트', '얼마', '적립', '청짜'],
#  ['업데이트', '업데이트'],
#  ['버킷리스트', '어딧', '나용', '어플', '업데이트', '이후', '수가'],
#  ['관리', '서비스', '연결', '조회', '연결', '무한', '반복', '공지', '불가', '잡고', '시간'],
#  ['요청', '회수', '제한', '이진', '계정', '설정', '도안', '설정'],
#  ['업뎃', '이후', '먹통', '네트워크', '상태', '다나', '빵빵', '전혀', '문제'],
#  ['카드', '등록', '인증서', '등록', '포기'],
#  ['조회', '서비스', '기약', '상태', '설치', '참고', '매우', '매우', '불편'],
#  ['기계', '답변', '상담사', '기분', '탈퇴', '가입', '빡세'],
#  ['로그인',
#   '까딱',
#   '까딱',
#   '그림',
#   '누구',
#   '아이디어',
#   '잘못',
#   '로그인',
#   '생각',
#   '그림',
#   '수정',
#   '해주시',
#   '감사'],
#  ['미니', '금고', '꽁꽁', '즐겨찾기', '수도', '위젯', '불편'],
#  ['실행', '소리', '거나', '대기업', '다운', '퀄리티'],
#  ['매번', '킬때', '마다', '카드', '변경', '불편', '기본', '결제', '수단'],
#  ['가끔', '오프라인', '결제', '번결', '제하', '최적화'],
#  ['교통카드', '여러', '부족', '여러', '창피해', '삼성'],
#  ['펀드',
#   '추천',
#   '수가',
#   '투자',
#   '수익률',
#   '그래프',
#   '투자',
#   '하루',
#   '이틀',
#   '지나',
#   '그래프',
#   '원래',
#   '부터',
#   '그래프',
#   '본인',
#   '이익'],
#  ['충전', '버튼', '거지', '업데이트', '찾기'],
#  ['와우',
#   '지네',
#   '제하',
#   '필요',
#   '한지',
#   '결제',
#   '진행',
#   '전화번호',
#   '인증',
#   '중간',
#   '겨우',
#   '결제',
#   '결제',
#   '감안',
#   '카뱅',
#   '관련',
#   '모든',
#   '지우'],
#  ['유아', '가지', '결재', '쓰기', '불편'],
#  ['신분증', '촬영', '제발', '달라', '고요', '촬영'],
#  ['어플', '오류', '개발자', '서비스', '담당자', '인식', '내부', '증상', '유선', '설명'],
#  ['래서',
#   '충전',
#   '계좌연결',
#   '송금',
#   '충전',
#   '어간',
#   '충전',
#   '결제',
#   '사이',
#   '인지',
#   '처럼',
#   '전하',
#   '될줗'],
#  ['접속', '이틀', '인증', '네트웍', '연결'],
#  ['장난', '투자', '목록', '과거', '버그'],
#  ['업데이트', '대기', '시간', '분도', '던데', '래그', '업데이트', '시간'],
#  ['구글플레이', '결제', '제하', '오류', '결제', '쓸모'],
#  ['마다', '황하', '기분', '누가', '일목요연', '시스', '테믹하', '처음', '기본', '알기'],
#  ['업데이트', '불편', '투자', '안보', '이나', '찾기', '투자', '분명', '회사', '수익', '책임'],
#  ['언제', '이후', '계좌', '정보', '업데이트'],
#  ['완성', '플랫폼', '오류', '실행', '강종'],
#  ['개불',
#   '탈퇴',
#   '계정',
#   '가입',
#   '서비스',
#   '계좌',
#   '해제',
#   '그거',
#   '제하',
#   '방법',
#   '서비스',
#   '계좌',
#   '해제',
#   '로그인',
#   '로그아웃',
#   '설치',
#   '실행',
#   '시간',
#   '재시'],
#  ['소리', '업댓', '전이'],
#  ['결제', '제공', '수가', '어플', '설치'],
#  ['카드', '출금', '일부', '출금', '인증번호', '어플', '렉', '아직까지'],
#  ['로그아웃', '로그인', '네트워크', '문제', '인터넷', '소리', '인지', '얼른', '조치'],
#  ['비번', '초기', '입력', '분뒤', '하자'],
#  ['지출', '분석', '공인', '인증서', '주민등록번호', '입력', '등록', '입력'],
#  ['검색', '이건'],
#  ['송금', '오류', '제대로', '역서', '모자라', '이상', '차이', '위조'],
#  ['일단',
#   '대출',
#   '한도',
#   '순차',
#   '작성',
#   '인증',
#   '문제',
#   '여기',
#   '서부',
#   '한도',
#   '조회',
#   '대출',
#   '신청',
#   '대출',
#   '신청',
#   '조회',
#   '조회',
#   '핑계',
#   '대출',
#   '신청'],
#  ['실행', '띠링', '귀가', '정도', '소리', '귀가', '아픔'],
#  ['휴먼', '계정', '등록', '실패', '분뒤'],
#  ['국사', '사람', '카드', '인증', '통신사', '한국', '거만', '그거', '감사'],
#  ['손님',
#   '큐알',
#   '결제',
#   '알림',
#   '처름',
#   '즉시',
#   '한시',
#   '간이',
#   '두시',
#   '간이',
#   '카운터',
#   '손님',
#   '일일이',
#   '당황',
#   '큐알',
#   '결제',
#   '즉시',
#   '알림',
#   '오도',
#   '개선',
#   '노트'],
#  ['연동', '결제', '시간', '개발', '관리'],
#  ['쓰레기',
#   '계정',
#   '로만',
#   '해지',
#   '가입',
#   '목록',
#   '정기',
#   '결제',
#   '기존',
#   '계정',
#   '해지',
#   '고객',
#   '센터',
#   '연락',
#   '구구절',
#   '이야기',
#   '친후',
#   '해지',
#   '어플',
#   '는걸',
#   '메뉴',
#   '바로',
#   '전화'],
#  ['정도', '쓸모', '어플', '쓰기', '해택'],
#  ['소리', '띠링', '처음', '소리'],
#  ['제발',
#   '중복',
#   '가입',
#   '해주시',
#   '가입',
#   '계정',
#   '탈퇴',
#   '정인지',
#   '수가',
#   '계정',
#   '로그인',
#   '공지',
#   '사항',
#   '제시',
#   '두번째',
#   '방법',
#   '수도',
#   '부탁'],
#  ['미니',
#   '금고',
#   '버킷리스트',
#   '꼭꼭',
#   '놨는',
#   '해지',
#   '놨나',
#   '대한',
#   '모든',
#   '정보',
#   '안보',
#   '뒤죽박죽',
#   '꼭꼭',
#   '증발',
#   '불안',
#   '신뢰',
#   '메뉴',
#   '중구',
#   '난방',
#   '미로'],
#  ['업데이트', '렉'],
#  ['불편', '에러', '가나', '움직', '이지'],
#  ['가도', '제대로', '인증', '정보', '어플'],
#  ['수수료', '현금', '수수료', '아타', '아직', '이체', '거래', '불편', '투자', '알림', '별로'],
#  ['시작', '띠링', '소리'],
#  ['이전', '버전', '미니', '금고', '킬때', '띠링', '소리', '최악'],
#  ['지방세', '전자', '고지서', '해지', '지하', '왜그', '런가', '신청', '다만'],
#  ['휴면', '계정', '처리', '등록', '재등'],
#  ['오류', '체크카드', '제대로'],
#  ['결제',
#   '송금',
#   '점검',
#   '시간',
#   '결제',
#   '축구',
#   '일찍',
#   '일어나서',
#   '결제',
#   '축구',
#   '시간',
#   '점검',
#   '잠도'],
#  ['모바일', '교통카드', '메뉴', '도저히'],
#  ['원래',
#   '병무청',
#   '문서',
#   '공인',
#   '인증서',
#   '정작',
#   '문서',
#   '다운로드',
#   '인터넷',
#   '페이지',
#   '감사',
#   '지네',
#   '어플',
#   '설치',
#   '해결',
#   '어플',
#   '해결',
#   '용량',
#   '절차',
#   '기억',
#   '악성코드',
#   '제외',
#   '최악',
#   '어플'],
#  ['모바일', '교통카드', '지하철', '마다', '승차', '처리'],
#  ['증권', '점검', '공지', '문제', '번다', '배부', '돼지', '최소한', '일주일', '공지'],
#  ['이모티콘', '결제', '결제', '상세', '한시', '간이', '시적', '오류', '신용카드', '결제', '보이'],
#  ['안녕',
#   '비밀번호',
#   '계정',
#   '인증',
#   '문자',
#   '메세지',
#   '아야',
#   '문자',
#   '오늘이',
#   '날인',
#   '매일',
#   '지나',
#   '전송',
#   '비번',
#   '기억',
#   '잘못',
#   '문제',
#   '해주시'],
#  ['알림',
#   '이후',
#   '갤럭시',
#   '노트',
#   '영원',
#   '참고',
#   '안드로이드',
#   '이하',
#   '보안',
#   '문제',
#   '최신',
#   '버전',
#   '업데이트',
#   '불가',
#   '구형',
#   '보안',
#   '때메',
#   '최신',
#   '오라',
#   '말로',
#   '사유',
#   '사람',
#   '대체',
#   '인증',
#   '수단',
#   '비트',
#   '출금',
#   '인증',
#   '거래소',
#   '이후',
#   '구형',
#   '보안',
#   '지원',
#   '안해',
#   '주신',
#   '제안',
#   '은사',
#   '아직',
#   '갤럭시',
#   '노트',
#   '시리즈',
#   '지원',
#   '당분간'],
#  ['제하',
#   '기전',
#   '카카',
#   '페쪽',
#   '결제',
#   '치면',
#   '결제',
#   '완료',
#   '페이지',
#   '보고',
#   '업뎃',
#   '반복',
#   '을지'],
#  ['마다', '소리', '설정', '데이트'],
#  ['이자', '모닝콜'],
#  ['투자', '현황', '대기', '펀드', '어제', '부터'],
#  ['지원', '별거', '블로그', '홍보'],
#  ['신분증', '인식', '대서', '발급', '재발', '신분증', '인식', '이안', '은어'],
#  ['시작', '소리', '지문', '인식', '실패', '각종', '인증', '실패'],
#  ['교통카드', '어도', '나중', '카드', '현금', '버스', '승차', '결제', '던데', '카드', '환불'],
#  ['로그인', '가입', '계정', '공지', '사항', '고하', '접근', '야합'],
#  ['로그인', '네트워크', '문제', '로그인', '에러', '탈퇴', '방법', '개선'],
#  ['신분증', '촬영', '잘못', '실명', '인증', '입금', '도안', '촬영'],
#  ['실행', '소리', '소리'],
#  ['교통카드', '메뉴', '보이지'],
#  ['계정',
#   '제해',
#   '가지',
#   '아이디',
#   '계정',
#   '로그인',
#   '가입',
#   '계정',
#   '로그인',
#   '로그인',
#   '을해',
#   '계정',
#   '지우',
#   '은사',
#   '이아',
#   '닌거',
#   '문제',
#   '개선',
#   '생각'],
#  ['시작', '랑딸랑', '소리', '소리', '핸드폰', '진동', '방법'],
#  ['럭키', '당첨', '설치', '로그인', '금융', '관련', '어플', '작동', '심각', '문제'],
#  ['졸라', '졸라', '점점', '미로', '직관', '미니', '금고', '불편', '치매', '예방', '어플'],
#  ['기껏',
#   '업데이트',
#   '미니',
#   '금고',
#   '화면',
#   '미니',
#   '금고',
#   '굳이',
#   '사람',
#   '마다',
#   '화면',
#   '편집',
#   '여분',
#   '미니',
#   '금고',
#   '위젯'],
#  ['간다', '예고', '자동', '이체', '사채', '업자', '통장', '압류', '대체'],
#  ['로그인', '아타'],
#  ['계정',
#   '중인',
#   '인증서',
#   '계정',
#   '진행',
#   '려면',
#   '기존',
#   '인증서',
#   '계정',
#   '먼지',
#   '어케',
#   '알라',
#   '아야',
#   '하루',
#   '종일'],
#  ['교통카드', '오류', '족하', '하차', '등등'],
#  ['타인',
#   '이보',
#   '주소',
#   '왜물',
#   '어보',
#   '주소',
#   '어보',
#   '프로그램',
#   '주소',
#   '수집',
#   '본인',
#   '확일',
#   '개인정보',
#   '가지',
#   '만큼',
#   '가지',
#   '주소',
#   '수집'],
#  ['조회', '증권사', '연결', '조회', '연결', '조회', '실제', '연결'],
#  ['전화번호', '로그인', '탈퇴', '아두'],
#  ['계좌', '충전', '수수료', '번만', '날렷잖아', '수수료', '가면', '충전', '경운', '충전', '유도인', '해결'],
#  ['처음', '로그인', '로그인', '이안'],
#  ['마치', '평점', '조작', '까운', '만큼', '평점'],
#  ['투자', '별로', '원금', '손실', '전문가', '추천', '투자', '어플', '스트레스'],
#  ['계좌', '송금', '금액', '부터', '을사', '계좌', '정보', '금액', '송금', '불편', '생각'],
#  ['결제', '제대로', '실행'],
#  ['리뷰', '자동', '충전', '대한', '송금', '발급'],
#  ['최신', '버전', '불구', '결제', '도하', '최신', '버전', '요하'],
#  ['관리', '증권', '예수금', '달러', '여지', '신한', '달러', '예수금', '포함', '던데', '순자', '불편'],
#  ['비트', '출금', '인증', '출금'],
#  [],
#  ['알리', '익스', '프레', '제하', '최신', '버전', '유효', '코드', '결제', '월초', '결제'],
#  ['미니', '금고', '화면', '사라', '불편', '가지'],
#  ['경험', '어플', '최악', '반복'],
#  ['업데이트', '수록', '사용자', '편의', '고려'],
#  ['인터페이스', '디른', '사람과', '이상하'],
#  ['명의', '언니', '가입', '명의', '로만', '불편'],
#  ['소리', '마다', '짜증'],
#  ['절대',
#   '어플',
#   '실망',
#   '본인',
#   '계정',
#   '연락',
#   '문의',
#   '문의',
#   '서로',
#   '기고',
#   '광고',
#   '문자',
#   '제명',
#   '핸드폰',
#   '개인',
#   '여러',
#   '고객',
#   '센터',
#   '개선',
#   '증권',
#   '리뷰',
#   '기고'],
#  ['댓글', '인증', '인증서', '도착', '다음', '화면', '안넘', '어감', '화남'],
#  ['휴대폰', '명의', '달라', '카드', '인증', '명의', '달라', '용법', '명의', '달라', '던데'],
#  ['지갑', '보이', '이전', '포인트', '쏠쏠', '포인트', '조금', '이벤트', '주하', '당첨', '확률', '누가'],
#  ['관리',
#   '금융',
#   '연동',
#   '공인',
#   '인증서',
#   '등록',
#   '연동',
#   '메세지',
#   '연결',
#   '금융',
#   '사가',
#   '없슴',
#   '차라리',
#   '오류',
#   '잘못',
#   '시간'],
#  ['투자', '지지', '펀드'],
#  ['기존', '정보', '이하', '상황'],
#  ['티몬', '제하', '오류', '보고'],
#  ['진동',
#   '소리',
#   '소리',
#   '벨소리',
#   '무음',
#   '그나',
#   '햅틱',
#   '진동',
#   '소름',
#   '쓰기',
#   '난리',
#   '햅틱',
#   '진동',
#   '설정',
#   '용한',
#   '장소',
#   '송금',
#   '띵동',
#   '보고',
#   '장난'],
#  ['신분증', '인식', '처럼', '인증', '입하'],
#  ['카메라', '고생', '포기', '한적'],
#  ['오프라인', '로그인'],
#  ['포인트', '번개', '장터', '문상', '사려', '선택', '창조'],
#  ['보이스피싱', '관리', '불편', '선물', '결제', '기존', '계정', '가입', '계정', '무한', '반복', '시작'],
#  ['쓰기', '기만', '장점'],
#  ['계좌', '연결'],
#  ['동일', '명의', '계정', '제발', '그게'],
#  ['서버', '후진', '왤케후져', '오류'],
#  ['업데이트', '이후', '결제', '요청', '시간', '초과', '분해', '지고', '안감'],
#  ['세이', '상부', '세이', '짜증', '세이', '상이', '살부', '세부', '해주시', '초등학생', '카드', '통장'],
#  ['인터넷',
#   '결제',
#   '기존',
#   '등록',
#   '카드',
#   '문제',
#   '카드',
#   '목록',
#   '결제',
#   '바코드',
#   '인식',
#   '결제',
#   '가면',
#   '불과',
#   '마전',
#   '어플',
#   '인식',
#   '어플',
#   '거기',
#   '서도',
#   '삼성',
#   '답임'],
#  ['인터넷',
#   '선택',
#   '결제',
#   '바코드',
#   '카메라',
#   '흐릿함',
#   '계좌',
#   '광고',
#   '결제',
#   '부터',
#   '수가',
#   '아래',
#   '화살표',
#   '루고',
#   '카메라',
#   '활성화',
#   '쌍욕',
#   '결재',
#   '인터넷',
#   '검색',
#   '광고',
#   '생각',
#   '필요',
#   '과정',
#   '통해',
#   '불편',
#   '거나',
#   '생각',
#   '거나',
#   '만해',
#   '리뷰',
#   '놨으'],
#  ['소리', '미디어', '소리', '최소', '소리', '제일', '크게'],
#  ['아이',
#   '허브',
#   '등록',
#   '신용카드',
#   '결제',
#   '주구',
#   '장창',
#   '통장',
#   '자동',
#   '충전',
#   '결제',
#   '일부러',
#   '용유도',
#   '이따',
#   '위로',
#   '신용카드',
#   '결제',
#   '수단',
#   '등록'],
#  ['실행', '유튜브', '뮤직', '스플래시', '로딩', '애니메이션', '사운드', '삽입', '는가'],
#  ['부족', '지고'],
#  ['어플', '킬때', '소리', '마다', '소리', '깜짝'],
#  ['송금', '손가락', '여자', '가입', '뭔가'],
#  ['짜증', '손가락', '다대', '인증', '이상'],
#  ['결제', '이상하', '사면', '충전', '대체', '인지'],
#  ['계정', '로그인', '계정', '로그인', '후재', '설치', '멀어떠케'],
#  ['갈라치', '뺑뺑', '가면', '아이디', '또드갈', '라카', '처음', '단계', '로그인', '반복'],
#  ['띠링',
#   '소리',
#   '누구',
#   '아이디어',
#   '그것',
#   '알림',
#   '볼륨',
#   '벨소리',
#   '볼륨',
#   '에바',
#   '기각',
#   '이정',
#   '도도',
#   '예상',
#   '라라'],
#  ['알림',
#   '휴면',
#   '계좌',
#   '전환',
#   '예정',
#   '최근',
#   '송금',
#   '휴면',
#   '계좌',
#   '전환',
#   '예정',
#   '알림',
#   '알림',
#   '잘못',
#   '접근',
#   '오늘',
#   '휴면',
#   '계좌',
#   '전환',
#   '예정',
#   '알림',
#   '거래',
#   '휴면',
#   '계좌',
#   '전환',
#   '예정',
#   '알림',
#   '조차'],
#  ['편리',
#   '관리',
#   '계좌',
#   '무료',
#   '송금',
#   '장점',
#   '구독',
#   '무료',
#   '음악',
#   '티빙',
#   '쇼핑',
#   '포인트',
#   '적립',
#   '쇼핑',
#   '유용',
#   '포인트',
#   '활용',
#   '장점',
#   '강점',
#   '밥값',
#   '전부'],
#  ['정랄', '개떡', '어플', '이구', '인증', '절차', '오류', '태반'],
#  ['업데이트',
#   '화면',
#   '개편',
#   '얼마',
#   '전만',
#   '관리',
#   '계좌',
#   '미니',
#   '금고',
#   '버킷리스트',
#   '더보',
#   '기탭',
#   '불편'],
#  ['명의', '본인인증', '휴면', '계정', '로그인', '묶여서'],
#  ['결제', '기기', '본인인증', '만해', '굳이', '기기', '고민'],
#  ['탈퇴', '이후', '가입', '불편'],
#  ['연동', '카드', '금액', '공인', '인증서', '인증', '얼마', '썻는', '이안'],
#  ['개도', '로그인', '제대로', '리얼', '쓰레기', '앱임', '평가원', '쓰레기', '인증'],
#  ['연령', '세인', '이상', '살인', '이상', '앞뒤', '주기도'],
#  ['기기', '초기', '설치', '계정', '쓰래', '핸드폰', '번호'],
#  ['실행', '소리', '해제'],
#  ['계정', '로그인', '본인인증', '가입', '계정', '무한', '반복', '사람'],
#  ['특정', '문구', '어플', '종료', '설치', '로그인', '조차', '회사', '회사', '어플', '들보', '최적화'],
#  ['교통카드', '결제', '짜증'],
#  ['스타벅스',
#   '커피',
#   '만들기',
#   '이벤트',
#   '초반',
#   '완성',
#   '스타벅스',
#   '기프티콘',
#   '매진',
#   '겨우',
#   '포인트',
#   '지인',
#   '친구',
#   '가족',
#   '사람',
#   '설득',
#   '스타벅스',
#   '커피',
#   '기프티콘',
#   '생각',
#   '설랬는데',
#   '오히려',
#   '이나',
#   '손해',
#   '포인트',
#   '주가',
#   '하락',
#   '원인'],
#  ['갈라', '는가', '교통카드', '지하'],
#  ['교통카드',
#   '서비스',
#   '광고',
#   '처럼',
#   '제창',
#   '아이콘',
#   '제대로',
#   '금액',
#   '대도',
#   '불구',
#   '부족',
#   '오류',
#   '하루'],
#  ['송금',
#   '이체',
#   '결제',
#   '주식',
#   '매매',
#   '등등',
#   '거래',
#   '모든',
#   '종류',
#   '대해',
#   '조금',
#   '거래',
#   '수수료',
#   '부과',
#   '궁금',
#   '부과',
#   '굳이',
#   '필요성',
#   '수가',
#   '답변'],
#  ['계좌', '조회', '갱신', '샐러드'],
#  ['결과', '간혹', '오류', '부분', '해결', '어진'],
#  ['업데이트', '지네'],
#  ['주민등록번호', '제대로'],
#  ['간편', '연결', '마다', '시적', '연결', '굳이', '유조차', '대체', '연동'],
#  ['나이', '세인', '세로'],
#  ['탈퇴',
#   '해지',
#   '탈퇴',
#   '탈퇴',
#   '정기',
#   '결제',
#   '등록',
#   '탈퇴',
#   '가안',
#   '해지',
#   '탈퇴',
#   '도못',
#   '가입',
#   '불편',
#   '아침',
#   '고객',
#   '센터',
#   '전화',
#   '방법'],
#  ['만원', '단위', '로만', '송금', '충전', '단위'],
#  ['분리', '툭하면', '하나로', '합치', '이도', '구리', '구림'],
#  ['구글', '결제', '수단', '업데이트', '최신', '버젼', '결제', '설명'],
#  ['해외', '유저', '한국', '계좌', '카드'],
#  ['계좌연결', '바로', '콜라', '결제', '포인트', '신속', '입금', '이건'],
#  ['순자', '표기', '이상', '적금', '통장'],
#  ['아들',
#   '차비',
#   '만원',
#   '기존',
#   '계정',
#   '기존',
#   '계정',
#   '로그인',
#   '년전',
#   '잠깐',
#   '며칠',
#   '그동안',
#   '핸드폰',
#   '여러',
#   '계정',
#   '여러',
#   '기존',
#   '계정',
#   '수가',
#   '아들',
#   '만원'],
#  ['교통카드', '이모티콘'],
#  ['계좌연결', '마지막', '불가능'],
#  ['카드결제', '계좌', '잔고', '결제'],
#  ['헤피', '포인트', '멤버', '카드', '연동', '포인트', '적립', '포인트', '적립', '카드', '적립', '던데'],
#  ['처음', '설치', '계정', '로그인', '네트워크', '오류'],
#  ['아주',
#   '소비자',
#   '우롱',
#   '제대로',
#   '제주',
#   '프로',
#   '할인',
#   '프로모션',
#   '방적',
#   '종료',
#   '부모님',
#   '제하',
#   '오심',
#   '할인',
#   '카드',
#   '제하',
#   '글씨',
#   '언제',
#   '이벤트',
#   '종로',
#   '고객',
#   '가입',
#   '유치'],
#  ['펀드', '정도', '펀드', '지네'],
#  ['업데이트', '실행', '띠링', '소리', '듣기'],
#  ['다운', '체적', '오류', '곤란'],
#  ['거지',
#   '구글',
#   '제하',
#   '도록',
#   '신분',
#   '조심',
#   '구글',
#   '계정',
#   '자녀',
#   '감시',
#   '처럼',
#   '계정',
#   '동하',
#   '미성년',
#   '자녀',
#   '자녀',
#   '실수',
#   '구독',
#   '순간',
#   '구독',
#   '바로',
#   '취소',
#   '인증',
#   '통장',
#   '구글',
#   '바치',
#   '구글',
#   '계정',
#   '결제',
#   '비번',
#   '이나',
#   '지문',
#   '인증',
#   '허락',
#   '통장',
#   '뜬금',
#   '결제',
#   '발견',
#   '고객',
#   '센터',
#   '전화',
#   '구글',
#   '전화번호',
#   '통화',
#   '상담',
#   '이번',
#   '그나',
#   '만원',
#   '정도',
#   '연동',
#   '자녀',
#   '금액',
#   '얼마',
#   '결재',
#   '는걸',
#   '이번',
#   '대충',
#   '해결',
#   '모두',
#   '제거',
#   '할껍니',
#   '어도',
#   '여기저기',
#   '지갑',
#   '널렸으',
#   '나하',
#   '탈퇴',
#   '처럼',
#   '당하',
#   '후회',
#   '조심'],
#  ['전부',
#   '계좌',
#   '연동',
#   '계좌',
#   '역도',
#   '보이',
#   '계좌',
#   '연결',
#   '심지어',
#   '계좌',
#   '연결',
#   '업데이트',
#   '마찬가지'],
#  ['연결', '연결', '중단'],
#  ['아이디',
#   '탈퇴',
#   '로그인',
#   '계정',
#   '는걸',
#   '연결',
#   '계정',
#   '본인',
#   '명의',
#   '계정',
#   '지고',
#   '신건',
#   '멜론',
#   '연결',
#   '계정',
#   '이따',
#   '위인',
#   '시일',
#   '수정',
#   '부탁'],
#  ['짜증',
#   '세금',
#   '못내',
#   '코드',
#   '화면',
#   '벽돌',
#   '연체',
#   '관성',
#   '드디어',
#   '나라',
#   '미로',
#   '처럼',
#   '구나'],
#  ['증권',
#   '개설',
#   '신분증',
#   '사진',
#   '포기',
#   '문제',
#   '인지',
#   '카메라',
#   '문제',
#   '인지',
#   '도통',
#   '수기',
#   '도안',
#   '수동',
#   '촬영',
#   '계좌',
#   '개설',
#   '기하'],
#  ['계좌번호', '아야', '입금', '출금', '투자', '어도', '출금', '방법', '커녕', '계좌', '안보', '투자'],
#  ['모바일', '교통카드', '도데', '아들'],
#  ['캐릭터', '성공', '회사', '기술', '오류', '투성이'],
#  ['뱅이', '얼굴인식', '대출', '비교', '업계'],
#  ['세상',
#   '부어',
#   '모자',
#   '계정',
#   '로그인',
#   '시간',
#   '중인',
#   '와이파이',
#   '데이터',
#   '핸드폰',
#   '전원',
#   '다해',
#   '네트워크',
#   '환경',
#   '불안',
#   '로그인',
#   '심지어',
#   '라이벌',
#   '회사',
#   '고객',
#   '센터',
#   '운영',
#   '제대로'],
#  ['금융', '연결', '완료', '상조', '회하', '등록', '무한', '반복'],
#  ['제창', '고하'],
#  ['펀드', '투자', '불안', '해결', '투자', '리해'],
#  ['공동', '인증서', '오기', '보이', '공동', '인증서', '오라', '계좌연결', '불안', '정합'],
#  ['마다', '인지', '인지', '소리', '주변', '민폐', '버스', '깜놀', '방법', '누구', '아이디어'],
#  ['플레이스토어', '결제', '수단', '설치', '짜증'],
#  ['위메프',
#   '마이',
#   '런거',
#   '결제',
#   '증권',
#   '계좌',
#   '업데이트',
#   '증권',
#   '생각',
#   '이건',
#   '강제',
#   '송금',
#   '바로',
#   '통장',
#   '이번',
#   '증권',
#   '통장',
#   '증권',
#   '개설',
#   '거부권'],
#  ['미성년', '미니카', '그게', '연결', '충전', '연동', '입출금', '계좌', '미성년', '여서'],
#  ['업데이트'],
#  ['미니', '금고', '금고', '점점', '찾기', '불편'],
#  ['처음', '버스', '카드', '오늘', '지하철', '버스', '답변'],
#  ['업뎃', '이후', '전하', '사라', '하루', '종일', '안보', '짜증'],
#  ['버킷리스트', '월부', '역도', '사라'],
#  ['별로'],
#  ['투자', '화면', '먹통', '어제', '래서', '시적', '현상', '오늘'],
#  ['마켓',
#   '컬리',
#   '처럼',
#   '마켓',
#   '컬리',
#   '결제',
#   '쿠폰',
#   '마켓',
#   '컬리',
#   '사람',
#   '고요',
#   '마켓',
#   '컬리',
#   '할인',
#   '혜택',
#   '만원',
#   '정도',
#   '결제',
#   '쿠폰'],
#  ['인증서', '시스템', '오류로', '관리'],
#  ['상한', '이벤트', '치하'],
#  ['바코드', '안보', '런가', '어도', '바코드', '안보'],
#  ['관리', '서비스', '몆달', '지네', '에버', '공지', '관리', '서비스', '펀드', '아버', '고민'],
#  ['개편',
#   '누가',
#   '일부러',
#   '갈리',
#   '거래',
#   '조회',
#   '장님',
#   '인지',
#   '조회',
#   '담달',
#   '려면',
#   '위로',
#   '개편',
#   '사람',
#   '정신과',
#   '아가',
#   '보삼'],
#  ['이후', '거래', '업데이트'],
#  ['로그인', '로그아웃', '그게', '탈퇴'],
#  ['시작', '거리'],
#  ['능력', '개발자', '이건', '완성', '수준'],
#  ['업데이트', '새마을금고', '연동', '새마을', '금고', '연동', '주로', '새마을'],
#  ['카드', '은근', '만해', '의도', '다분'],
#  ['연동', '카드', '제휴', '사나', '국세청', '모든', '연동'],
#  ['동생', '계정', '등록', '못해', '수정', '로그아웃', '아이디', '내껀데', '등록', '동생'],
#  ['로그인', '불편', '쓰기', '지네'],
#  ['어쩌라구', '핸드폰', '사람', '송금', '여요'],
#  ['계정', '탈퇴', '가입', '탈퇴', '가입', '조치', '부탁'],
#  ['펀드', '가기', '지우', '설치', '해결', '방법'],
#  ['개도', '선물', '오류', '이메일', '개인', '난하'],
#  ['업데이트'],
#  ['통합', '관리', '뷸편함'],
#  ['최악'],
#  ['오류', '금고', '버킷리스트', '오늘', '가량', '동안', '금고', '충전', '금액'],
#  ['처음', '시작', '전화번호'],
#  ['계좌', '개설', '도하', '대체', '하자', '순자', '계좌', '개설', '지하', '방법', '불친절', '어플'],
#  ['미만', '저번', '로그인', '탈퇴', '미만'],
#  ['세부'],
#  ['택시', '투자', '서비스', '재개', '해주시', '거나', '종료', '시오'],
#  ['자동',
#   '십일',
#   '만오',
#   '천십원',
#   '오후',
#   '자동',
#   '맘대로',
#   '결제',
#   '당하',
#   '금액',
#   '결제',
#   '이건',
#   '환불'],
#  ['부동산', '소액', '바킷', '리스트', '한눈', '보이', '꽁꽁', '수익', '직관', '성도', '개불'],
#  ['소리', '마란', '띠링', '의미', '갈수록', '사람'],
#  ['휴먼', '계정', '복구', '탈퇴'],
#  ['오늘', '우기', '여러', '투자', '클릭', '기네'],
#  ['계정',
#   '기존',
#   '계정',
#   '탈퇴',
#   '기존',
#   '계정',
#   '로그인',
#   '탈퇴',
#   '하든',
#   '로그인',
#   '신규',
#   '계정',
#   '바로',
#   '탈퇴',
#   '문구',
#   '부터',
#   '계정',
#   '자주',
#   '제하',
#   '사람',
#   '수가'],
#  ['새볔', '결제', '실행', '최악'],
#  ['데이터', '대기', '중이', '전화기', '제해', '보고'],
#  ['우리카드', '등록', '로봇', '어보', '업데이트', '고해', '모두', '업데이트'],
#  ['띠링', '소리'],
#  ['투자', '증권', '금융', '사연', '아이디', '도안', '공인', '인증서'],
#  ['매장', '결제', '할로윈', '대서', '편의점', '결제', '주네'],
#  ['개븽', '어플', '공동', '인증서', '인증', '여러', '벌레', '어플'],
#  ['결제', '결제', '실행'],
#  ['바코드'],
#  ['일부', '모든', '제창', '안넘', '서비스', '해지', '가입', '여전', '먹통'],
#  ['점검', '짜증', '이후', '고요'],
#  ['진심', '로우', '성공', '결제', '업뎃', '고하'],
#  ['인터넷', '주문', '미니', '계정', '연동', '오류', '리뷰', '유효', '계좌', '해결'],
#  ['투자', '증권', '나무', '계좀', '부터', '던데', '여전'],
#  ['카드',
#   '작년',
#   '발급',
#   '카드',
#   '버스비',
#   '제하',
#   '비용',
#   '이나',
#   '고객',
#   '센터',
#   '전화',
#   '초기',
#   '충전',
#   '만원',
#   '유지',
#   '위해',
#   '자동',
#   '이체',
#   '고해',
#   '오늘',
#   '버스'],
#  ['멤버', '자동', '적립'],
#  ['전혀', '잔고', '출하', '인지', '타계', '잔고', '변화', '달이', '도록', '어도', '전혀'],
#  ['보나', '몇개'],
#  ['펀드', '즉석', '계산', '에나', '입금', '불편', '펀드', '만원', '원정', '하락', '투자'],
#  [],
#  ['얼마나', '중앱', '구시대', '조잡'],
#  ['전부',
#   '족하',
#   '오늘',
#   '환승',
#   '부족',
#   '고객',
#   '센터',
#   '전화',
#   '센터',
#   '주말',
#   '월요일',
#   '전액',
#   '환불',
#   '거지',
#   '별로'],
#  ['리뷰',
#   '띠링',
#   '소리',
#   '제발',
#   '해결',
#   '공모',
#   '청약',
#   '알림',
#   '제거',
#   '대체',
#   '서하',
#   '컴맹',
#   '런것',
#   '도무지',
#   '수다'],
#  ['로그인', '계정', '정보', '탈퇴', '그거'],
#  ['페미', '해명', '후속', '조치', '중단'],
#  ['카택', '짜증', '페이도', '쓰기', '언드'],
#  ['비트코인', '전자지갑'],
#  ['커피', '이벤트', '다모아', '커피', '선택', '강제'],
#  ['구들',
#   '회전초밥',
#   '얼마',
#   '거지',
#   '분명',
#   '만원',
#   '만원',
#   '거지',
#   '봣는데',
#   '결제',
#   '카페',
#   '결제',
#   '머리',
#   '증말',
#   '만원'],
#  ['리뷰', '답변', '로봇', '사람', '이면', '영혼', '붙여넣기'],
#  ['비트', '출금', '인증', '주소', '요구', '거지'],
#  ['증권', '연결', '말썽'],
#  ['카드',
#   '지출',
#   '파악',
#   '관리',
#   '공동',
#   '인증서',
#   '등록',
#   '처음',
#   '상태',
#   '공동',
#   '인증서',
#   '발급',
#   '조치',
#   '부탁'],
#  ['투자', '버튼', '페이지', '자동', '지네'],
#  ['휴먼', '계정'],
#  ['전형',
#   '사기',
#   '이벤트',
#   '커피',
#   '이나',
#   '고지',
#   '포인트',
#   '뭔가',
#   '소비자',
#   '기만',
#   '금감원',
#   '민원',
#   '공정위',
#   '민원',
#   '아직',
#   '정신',
#   '생각',
#   '마케팅',
#   '기획',
#   '여러분',
#   '공정위',
#   '금감원',
#   '민원',
#   '소비자',
#   '기만'],
#  ['이벤트', '이따', '위로', '할인', '날짜', '도안', '난하', '도아', '기름값'],
#  ['평소', '카드결제', '결제', '알리', '결제', '계좌연결', '인증', '요구', '나니', '쿠폰'],
#  ['짜증', '신용정보', '변경', '알림', '증권', '수익', '알림'],
#  ['구동', '소리'],
#  ['불편', '고객', '센터', '바로', '직통', '전화', '고요'],
#  ['카드', '카드', '번호', '유효', '기간', '검색', '본대', '구석', '박아'],
#  ['버킷리스트', '미니', '금고', '안보', '여요', '업뎃', '불편'],
#  [],
#  ['분명', '세이', '상가', '살이'],
#  ['누가', '부터', '맘대로', '대신', '부터'],
#  ['원단', '위로', '충전', '그것', '개선'],
#  ['실행', '띠링', '소리', '이나', '아직', '라라', '초심', '완전'],
#  ['변경', '모주', '알리', '해지', '위치', '알림', '이전', '해지', '방법', '주네'],
#  ['교통카드', '서비스', '안보', '이나'],
#  ['여기', '배달', '포인트', '입력'],
#  ['글로벌',
#   '혜택',
#   '커피',
#   '교환',
#   '모바일',
#   '교환',
#   '타임',
#   '자마자',
#   '소진',
#   '사람',
#   '그거',
#   '기타',
#   '타이머',
#   '자마자',
#   '소진',
#   '제대로'],
#  ['부동산', '투자', '관련', '얼마', '순간'],
#  ['로그인', '인증', '동의', '짜증'],
#  ['당장', '결제', '업데이트', '강요', '뭔가'],
#  ['이건', '사기', '신고', '천원', '전하', '자동', '만원', '결제', '나머지', '금액', '취소'],
#  ['가입', '등록', '뭔가'],
#  ['투자', '펀드', '수익률', '보고'],
#  ['아주', '탈퇴', '오지', '여즘', '논란', '사람', '생각', '전혀'],
#  ['용돈', '구분', '쓰기'],
#  ['본인인증', '전화번호', '입력'],
#  ['치하', '열기'],
#  ['최악', '나인', '인증'],
#  ['금고', '기지'],
#  ['기존', '결제', '불편', '기존', '불편'],
#  ['기기', '관리자', '제한', '송금', '카카오페이지', '지지'],
#  ['미니', '연동'],
#  ['구가', '보넷능데', '아지', '어케해', '야합', '최악'],
#  ['결재', '다운', '결재', '해결', '방법'],
#  ['혐기', '불매', '중인', '눈치', '팝업', '광고'],
#  ['처음', '전화', '관리', '허용'],
#  ['처리',
#   '거지',
#   '탈퇴',
#   '구서',
#   '서비스',
#   '해지',
#   '해달',
#   '나날이',
#   '고객',
#   '센터',
#   '통화',
#   '펀드',
#   '해지',
#   '다라',
#   '언제',
#   '라그',
#   '래서',
#   '처리',
#   '시나',
#   '탈퇴',
#   '불편'],
#  ['금융', '사연', '연결'],
#  ['로그인', '몆번', '이나', '배부'],
#  ['투자', '부분', '화면', '한참'],
#  ['광고'],
#  [],
#  ['적립', '포인트', '유효', '기간'],
#  ['제한', '계정'],
#  ['아야', '하나로', '통일'],
#  ['지인',
#   '더치페이',
#   '회원',
#   '가입',
#   '억지로',
#   '가입',
#   '동안',
#   '유지',
#   '가입',
#   '동의',
#   '사람',
#   '명의',
#   '대신',
#   '억지로',
#   '회원',
#   '가입',
#   '강도',
#   '자시',
#   '기분',
#   '탈퇴',
#   '플랫폼',
#   '경제',
#   '라며',
#   '주가',
#   '볼모',
#   '잡고',
#   '강도짓',
#   '나름',
#   '대한민국',
#   '기업인'],
#  ['화면'],
#  ['지출', '조회', '공동', '인증서'],
#  ['오늘', '가정', '이모티콘', '부모님', '송금', '대로', '송금', '은사', '계좌'],
#  ['오류', '상담', '시간', '분기', '다리', '상담'],
#  ['교통카드', '페이지', '해결'],
#  ['인증', '문자', '오지'],
#  ['어제', '마트', '쿠폰', '유용'],
#  ['코드', '스캔', '결제', '이외', '선택', '불가'],
#  ['걸스', '쿠폰', '하필', '이면', '뿌리', '골로', '러시', '주의'],
#  ['교통카드', '충전', '환불', '수수료'],
#  ['요즘', '시대', '남성혐오', '식이', '최악', '갈리아', '금고'],
#  ['애초', '업빗', '손절', '제발', '처신', '똑바로'],
#  ['생각', '이상', '쓸모', '어플', '무방'],
#  ['궁금', '이상만'],
#  ['부동산', '투자', '현황', '투자', '투자', '현황', '업데이트', '보이'],
#  ['증권', '매월', '정보', '수가'],
#  ['휴먼', '계정', '복귀', '어떡'],
#  ['어린이', '완전', '사기', '어린이'],
#  ['저기', '서비스', '어캐', '어도'],
#  ['위메프', '결제', '할인', '거기', '이상', '임마'],
#  ['젠데', '투자', '클릭', '지질'],
#  ['투자', '카테고리', '전혀', '화면'],
#  ['자동', '이체', '정지'],
#  ['최소', '만원', '충전', '이건', '짜증'],
#  ['자주'],
#  ['업데이트', '이후', '결제'],
#  ['투자', '화면'],
#  ['관리', '현황', '업데이트'],
#  ['이상인', '가입'],
#  ['거지',
#   '계정',
#   '계정',
#   '동생',
#   '계정',
#   '로그인',
#   '안돼드',
#   '고요',
#   '동생',
#   '저걸',
#   '한적',
#   '동생',
#   '현상',
#   '계정',
#   '뜨드',
#   '고요',
#   '상담',
#   '상담',
#   '나머지',
#   '단순',
#   '오류',
#   '버그'],
#  ['시간', '오래'],
#  ['교통카드', '갑자'],
#  ['인증번호', '인증', '시간'],
#  ['미만'],
#  ['계정', '탈퇴', '로만', '계정'],
#  ['탈퇴',
#   '계정',
#   '임티결',
#   '제하',
#   '만원',
#   '설치',
#   '저쩌',
#   '거지',
#   '본인인증',
#   '대체',
#   '부터',
#   '짜증',
#   '시간',
#   '낭비'],
#  ['청구도', '보험', '청구', '서비스', '연락', '쓰지맙시', '어플', '익일', '입금'],
#  ['계좌', '이체', '내야', '당신', '신고', '당하'],
#  ['충전', '최소', '만원', '천원', '해주시'],
#  ['불편'],
#  ['엄마', '엄마', '저희', '이떻해', '세로', '조금', '이따', '나라', '시간'],
#  ['인증서', '비밀번호'],
#  ['본인인증', '신용카드', '공인', '인증서'],
#  ['통장', '얼마', '계좌', '결하', '나왓는데'],
#  ['만원', '단위', '충전'],
#  ['메뉴', '증권', '투자', '금액', '표시', '그래프', '반영'],
#  ['앱내', '알코', '왜안'],
#  ['투자', '화면', '펀드'],
#  ['통장'],
#  ['행복', '실패'],
#  ['이벤트', '다단계', '느낌'],
#  ['기기', '관리자', '제한', '리지'],
#  ['구글', '로그인', '만고', '치면'],
#  ['아직', '바서', '모름'],
#  ['업뎃강', '요하', '문어'],
#  ['투자', '재미'],
#  ['미니', '금고'],
#  ['결제', '제하', '애하'],
#  ['계좌', '쓰래'],
#  ['투자자',
#   '우롱',
#   '온라인',
#   '투자',
#   '어도',
#   '통해',
#   '투자',
#   '청산',
#   '서비스',
#   '통수',
#   '투자',
#   '서비스',
#   '투자'],
#  [],
#  ['카테고리'],
#  ['누구', '마음대로', '마켓', '컬리', '쿠폰'],
#  ['장난', '오류'],
#  ['중인', '유저', '기기', '관리자', '제한', '해결'],
#  ['만원', '만원'],
#  ['삼성', '계좌연결'],
#  ['민지원', '개뿔', '불편', '민지원', '계산기', '깔았드', '역시'],
#  ['인터넷',
#   '검색',
#   '이번',
#   '재난',
#   '지원',
#   '검색',
#   '국민',
#   '원금',
#   '계산기',
#   '궁금',
#   '문의',
#   '드립',
#   '인터넷',
#   '검색',
#   '국민',
#   '원금',
#   '계산기'],
#  ['탈퇴', '기적', '출금', '탈퇴', '로그인', '불가', '계정', '로그인', '방법'],
#  ['부동산', '투자', '바로', '이자', '무책임', '상장도', '아야'],
#  ['마지막', '인생', '역전', '어도'],
#  ['카드', '연동'],
#  ['송금', '송금', '얼마', '매번', '관리', '번거', '로움', '금융', '어플', '송금'],
#  ['쓰레기'],
#  ['아이디'],
#  ['펀드', '투자', '현황', '수정'],
#  ['불편'],
#  ['오늘', '로그인', '이벤트', '응모', '그때', '부터', '직전', '작용', '계시'],
#  ['펀드', '운영', '제대로'],
#  ['결제', '실패', '제한', '뭐임'],
#  ['럭키', '백원'],
#  ['투자', '지지'],
#  ['관리', '증권', '연결', '부탁', '드립', '전이', '동기화'],
#  ['수가'],
#  [],
#  ['모주', '알림', '서하', '꽁꽁'],
#  ['짜증',
#   '진심',
#   '고객',
#   '대해',
#   '배려',
#   '안함',
#   '고객',
#   '센터',
#   '어르신',
#   '어른',
#   '전화',
#   '일부러',
#   '상담',
#   '정도',
#   '회사',
#   '불편',
#   '사람',
#   '표현',
#   '불쾌감',
#   '불편',
#   '쓰레기'],
#  ['만듬'],
#  ['계좌', '입력', '본인인증', '인증', '전화', '계좌', '연결', '상태', '계좌', '미니', '라서', '부하'],
#  ['삼성'],
#  ['간단', '인정이'],
#  ['카드', '수업', '결제', '상담', '요청'],
#  ['깡통', '요란', '무엇', '잡스', '럽노', '앵꼽', '러버'],
#  ['신한', '금융투자', '관리', '국내', '주식', '해외', '주식', '업데이트'],
#  ['탈퇴', '계정', '강제', '연동', '계정', '덕분', '고객', '유치', '계시'],
#  ['관리', '증권', '던데'],
#  ['처음', '사용자', '입금', '입금자'],
#  ['럭키'],
#  ['주식', '배때', '개인정보'],
#  ['본인인증'],
#  ['에이', '오죽', '당신', '보이스피싱', '패가', '지고', '결젤', '아가', '니야', '근대'],
#  ['제발', '탈퇴', '제발', '계정', '등록', '하자'],
#  ['아직'],
#  ['신용카드', '처럼'],
#  ['이따', '구로', '현금', '결제', '유도'],
#  ['리뷰', '남혐', '논란', '문의', '담당', '직원', '징계', '문의', '답변', '리뷰', '그게', '해결'],
#  ['수수료',
#   '차감',
#   '매매',
#   '손익',
#   '정보',
#   '미국증시',
#   '수입',
#   '미국',
#   '증시',
#   '실시간',
#   '시세',
#   '업데이트',
#   '과거',
#   '버전',
#   '최신',
#   '버전',
#   '다행',
#   '투자',
#   '회사',
#   '업데이트',
#   '최근',
#   '업데이트',
#   '아주',
#   '과거',
#   '버전'],
#  ['저런',
#   '정보',
#   '차원',
#   '다만',
#   '거래',
#   '차이',
#   '거래',
#   '거나',
#   '주문',
#   '정정',
#   '손해',
#   '생체',
#   '인식',
#   '에러',
#   '매매',
#   '위해',
#   '전용',
#   '단말기',
#   '선정',
#   '주문',
#   '속도',
#   '높이',
#   '필요',
#   '커스터',
#   '마이',
#   '예약',
#   '매매',
#   '체결',
#   '매매',
#   '정정',
#   '대한',
#   '직관',
#   '세팅',
#   '만큼',
#   '니지',
#   '강점',
#   '관성',
#   '기존',
#   '엑셀',
#   '차트',
#   '매매',
#   '패턴',
#   '진일'],
#  ['미성년',
#   '자인',
#   '불편',
#   '옛날',
#   '화면',
#   '송금',
#   '버튼',
#   '옛날',
#   '불편',
#   '거기',
#   '왼쪽',
#   '화면',
#   '선택',
#   '미성년',
#   '자라',
#   '선택',
#   '업데이트'],
#  ['결제',
#   '간단',
#   '결제',
#   '이지',
#   '일부',
#   '가야',
#   '심지어',
#   '메뉴',
#   '조차',
#   '불가능',
#   '존재',
#   '메인',
#   '즐겨찾기',
#   '이외',
#   '전체',
#   '찾기',
#   '디자인',
#   '생각',
#   '정도',
#   '제일',
#   '당하',
#   '생각'],
#  ['증권',
#   '계좌',
#   '개설',
#   '이후',
#   '증권사',
#   '지하',
#   '해지',
#   '버튼',
#   '찾기',
#   '뿐더러',
#   '해지',
#   '해지',
#   '신청',
#   '계좌',
#   '외화',
#   '출금',
#   '해달',
#   '소액',
#   '달러',
#   '예수금',
#   '환전',
#   '신청',
#   '최소',
#   '금액',
#   '달러',
#   '라며',
#   '환전',
#   '원화',
#   '만원',
#   '입금',
#   '달러',
#   '환전',
#   '전액',
#   '환전',
#   '신청',
#   '여전',
#   '소액',
#   '달러',
#   '계좌',
#   '남아',
#   '계좌',
#   '해지',
#   '불가능',
#   '과정',
#   '이나',
#   '반복',
#   '예수금',
#   '달러',
#   '환전',
#   '수도',
#   '출금',
#   '수도',
#   '계좌',
#   '해지',
#   '도적',
#   '생각',
#   '증권',
#   '절대',
#   '시오',
#   '혈압'],
#  ['주식',
#   '계좌',
#   '개설',
#   '위해',
#   '신분증',
#   '사진',
#   '제대로',
#   '인식',
#   '촬영',
#   '정보',
#   '제대로',
#   '하서',
#   '직접',
#   '입력',
#   '신분증',
#   '발급',
#   '날짜',
#   '다음',
#   '단계',
#   '분명',
#   '동일',
#   '보고',
#   '입력',
#   '보고',
#   '개도'],
#  ['건드',
#   '리지',
#   '수시',
#   '카운트',
#   '나중',
#   '상단',
#   '사라',
#   '동안',
#   '카운트',
#   '짜증',
#   '친구',
#   '대결',
#   '멋대로',
#   '카운트',
#   '대결',
#   '의미',
#   '래서',
#   '카운트',
#   '삼성',
#   '헬스',
#   '최소',
#   '이상',
#   '제일',
#   '어플',
#   '상단',
#   '하루',
#   '수시',
#   '음수',
#   '비교'],
#  ['공모',
#   '알림',
#   '정보',
#   '정확',
#   '달리',
#   '간간',
#   '부정',
#   '공모',
#   '청약',
#   '이나',
#   '상장',
#   '알림',
#   '세부',
#   '사항',
#   '일정',
#   '당사항',
#   '청약',
#   '시작',
#   '어도',
#   '공모',
#   '예정',
#   '최저',
#   '최고',
#   '거나',
#   '경쟁률',
#   '마감',
#   '대기',
#   '거나',
#   '중대',
#   '오류',
#   '처음',
#   '실수',
#   '여기',
#   '플레인',
#   '시스템',
#   '오류',
#   '먹통',
#   '정보',
#   '부서',
#   '실수',
#   '케이스',
#   '적도',
#   '당하',
#   '정상화',
#   '부탁'],
#  ['주식',
#   '주문',
#   '방법',
#   '이전',
#   '버전',
#   '사항',
#   '랩탑',
#   '액셀',
#   '매매',
#   '판이',
#   '증권사',
#   '어플',
#   '주문',
#   '가가',
#   '매매',
#   '종가',
#   '대비',
#   '몇퍼',
#   '인지',
#   '주문',
#   '금액',
#   '주문',
#   '수량',
#   '입력',
#   '주문',
#   '금액',
#   '얼마',
#   '인지',
#   '자동',
#   '계산',
#   '버전',
#   '최총',
#   '주문',
#   '이전',
#   '버전',
#   '주문',
#   '수량',
#   '비율',
#   '형태',
#   '직관',
#   '현재',
#   '예수금',
#   '퍼센트',
#   '구매',
#   '구매',
#   '구매',
#   '주문',
#   '수량',
#   '레이'],
#  ['주식',
#   '거래',
#   '초사',
#   '이로',
#   '거래',
#   '채결',
#   '지면',
#   '손해',
#   '예약',
#   '주문',
#   '차트',
#   '용도',
#   '로만',
#   '는걸',
#   '추천',
#   '어플',
#   '거래',
#   '손해',
#   '막심',
#   '초당',
#   '가격',
#   '채결',
#   '마음',
#   '조마조마',
#   '짜증'],
#  ['레전드',
#   '교통카드',
#   '지갑',
#   '일반',
#   '페이지',
#   '교통카드',
#   '충전기',
#   '리뷰',
#   '수정',
#   '검색',
#   '알코',
#   '스캔',
#   '결제',
#   '결제',
#   '과정',
#   '불편',
#   '화면',
#   '단순',
#   '절차',
#   '간단',
#   '포인트',
#   '매번',
#   '짜증',
#   '취소',
#   '제하',
#   '광고',
#   '공간',
#   '자주'],
#  ['이번',
#   '업데이트',
#   '최악',
#   '호가',
#   '거나',
#   '결정',
#   '선택',
#   '이건',
#   '반대',
#   '매수',
#   '매도',
#   '매도',
#   '수하',
#   '사고',
#   '속출',
#   '거기',
#   '호가',
#   '창내',
#   '숫자',
#   '제대로',
#   '보이지',
#   '게다가',
#   '증권사',
#   '처럼',
#   '매매',
#   '동향',
#   '여주',
#   '언제',
#   '될런',
#   '이대',
#   '증권사',
#   '바꿔얄',
#   '금일',
#   '매매',
#   '호가',
#   '창의',
#   '잔량',
#   '실제',
#   '잔량',
#   '주식',
#   '매매',
#   '중단'],
#  ['증권',
#   '인터페이스',
#   '엉터리',
#   '직관',
#   '이지',
#   '기획',
#   '자가',
#   '자기',
#   '생각',
#   '대로',
#   '매번',
#   '계좌',
#   '입금',
#   '송금',
#   '증권',
#   '계좌',
#   '입금',
#   '마다',
#   '사장',
#   '바늘',
#   '화가',
#   '숨은그림',
#   '찾기',
#   '이건',
#   '장사',
#   '일부러',
#   '계좌',
#   '입금',
#   '증권',
#   '메뉴',
#   '쓰기'],
#  ['인증',
#   '방법',
#   '주민등록증',
#   '주민등록증',
#   '언제',
#   '발급',
#   '기억',
#   '저번',
#   '인적',
#   '일로',
#   '상황',
#   '이번',
#   '상황',
#   '주민등록증',
#   '인증',
#   '이상',
#   '인증',
#   '방법'],
#  ['증권',
#   '베타',
#   '아직',
#   '런가',
#   '부족',
#   '보이',
#   '소액',
#   '용해',
#   '보고',
#   '아직',
#   '통장',
#   '자동',
#   '충전',
#   '불편',
#   '기대',
#   '생각',
#   '별로',
#   '증권',
#   '플러스',
#   '연동',
#   '래야',
#   '그나'],
#  ['업데이트', '메뉴', '충전', '버튼', '기본', '충전', '버튼', '스트레스', '짜증'],
#  ['어이',
#   '자동',
#   '이체',
#   '잠깐',
#   '계좌',
#   '송금',
#   '요하',
#   '고해',
#   '사진',
#   '인증',
#   '송금',
#   '필요',
#   '처리',
#   '송금',
#   '증권',
#   '업무',
#   '시간',
#   '라라',
#   '퇴근'],
#  ['개도',
#   '증권',
#   '가입',
#   '신분증',
#   '촬영',
#   '운전면허증',
#   '적성',
#   '기간',
#   '만료',
#   '기간',
#   '려면',
#   '민증',
#   '거부',
#   '당하',
#   '겨우',
#   '앵글',
#   '가입',
#   '신분증',
#   '계좌',
#   '영원'],
#  ['와이파이', '접속', '데이', '연결', '사이트', '어플', '문제', '가보', '접속', '실행'],
#  ['또래',
#   '비교',
#   '적금',
#   '만기',
#   '해지',
#   '해당',
#   '적금',
#   '통장',
#   '기록',
#   '반영',
#   '과거',
#   '비교',
#   '기록',
#   '이상하',
#   '가지',
#   '제보',
#   '유량',
#   '정도',
#   '반영',
#   '도록',
#   '달이',
#   '수두',
#   '데이터',
#   '집계',
#   '처리',
#   '방식',
#   '정정'],
#  ['증권',
#   '플렛폼좀',
#   '디테',
#   '관심',
#   '화면',
#   '장점',
#   '관심',
#   '목록',
#   '분할',
#   '관심',
#   '등록',
#   '해제',
#   '알람',
#   '일일이',
#   '불편'],
#  ['와이파이', '연결', '연결', '상태', '충전', '수가', '데이터', '마찬가지', '고요'],
#  ['업데이트',
#   '계좌',
#   '수수료',
#   '송금',
#   '수수료',
#   '부과',
#   '제한',
#   '출금',
#   '단위',
#   '조정',
#   '절하',
#   '제하',
#   '려면',
#   '매하',
#   '만원',
#   '제한',
#   '출금',
#   '최소',
#   '금액'],
#  ['지문',
#   '변경',
#   '지문',
#   '변경',
#   '등록',
#   '래서',
#   '등록',
#   '비번',
#   '입력',
#   '지문',
#   '단계',
#   '무한',
#   '지문',
#   '등록',
#   '지문',
#   '등록',
#   '비번',
#   '입력',
#   '지문',
#   '무한',
#   '반복',
#   '이예'],
#  ['업데이트', '이후', '우리카드', '연동', '체적', '매우', '불편', '불편', '아가', '노력', '정도', '쓰기'],
#  ['버킷리스트',
#   '퍼센',
#   '테이',
#   '계좌',
#   '보이',
#   '설정',
#   '색깔',
#   '보이',
#   '건줄',
#   '숨기',
#   '고요',
#   '인터페이스',
#   '직관',
#   '이지'],
#  ['미성년',
#   '등록',
#   '통장',
#   '충전',
#   '출금',
#   '본인인증',
#   '신분증',
#   '발급',
#   '일자',
#   '분류',
#   '학생',
#   '본인인증',
#   '방법'],
#  ['펀드', '투자', '메뉴', '아들', '어려움', '사용자', '이지', '개선'],
#  ['인증',
#   '하래',
#   '학생',
#   '신분',
#   '학생',
#   '신분',
#   '인증',
#   '운전면허증',
#   '주민등록증',
#   '인증',
#   '인증',
#   '불가능',
#   '여러'],
#  ['로만',
#   '려면',
#   '포기',
#   '가뜩이나',
#   '갈리',
#   '사용자',
#   '경험',
#   '개발',
#   '시나',
#   '펀드',
#   '지하',
#   '복잡',
#   '고객',
#   '센터',
#   '전화',
#   '연결',
#   '한참',
#   '다리',
#   '겨우',
#   '해지',
#   '생각',
#   '해지',
#   '버튼',
#   '아직',
#   '펀드',
#   '개미지옥',
#   '지옥',
#   '답답',
#   '서비스',
#   '요하',
#   '플하'],
#  ['쇼핑몰',
#   '제하',
#   '본인인증',
#   '어쩌구',
#   '인증',
#   '수단',
#   '결제',
#   '바로',
#   '바로',
#   '결제',
#   '인증',
#   '민증',
#   '아직',
#   '수도'],
#  ['업데이트', '불편', '캐쉬', '충전', '아보', '고객', '편의', '위해', '업데', '오히려', '불편'],
#  ['업데이트',
#   '마다',
#   '버퍼링',
#   '와이파이',
#   '생각',
#   '와이파이',
#   '업데이트',
#   '한가지',
#   '잔치',
#   '기술',
#   '업그레이드',
#   '신경',
#   '쓰기',
#   '신가'],
#  ['리지', '거래', '개선', '필요', '는걸', '리뷰', '보고', '잘못', '개선'],
#  ['점점', '업데이트', '업데이트', '수록', '불편', '해지'],
#  ['알림', '개선', '첫날', '부터', '정치가', '엉망', '혼자', '정치가', '절반', '버전', '하루걸러', '측정'],
#  ['등록',
#   '카드',
#   '만료',
#   '전화번호',
#   '등록',
#   '로그인',
#   '휴대폰인증',
#   '공지',
#   '사항',
#   '기존',
#   '계정',
#   '그것',
#   '로그인',
#   '데넘',
#   '기존',
#   '계정',
#   '계정',
#   '고하',
#   '방법',
#   '설명',
#   '계정',
#   '읍니'],
#  ['출금',
#   '검색',
#   '무한',
#   '로딩',
#   '진행',
#   '메뉴',
#   '가야',
#   '상적',
#   '것땜',
#   '현금',
#   '필요',
#   '한참',
#   '헤맷',
#   '개발',
#   '똑바로'],
#  ['결하', '어플', '동안', '어도', '반영', '기본', '헬스', '어플', '동하', '가능성', '어보'],
#  ['변경', '사항', '간편', '결제', '차라리', '업데이트'],
#  ['탈퇴',
#   '가입',
#   '에쓰',
#   '계정',
#   '로그인',
#   '지지',
#   '기존',
#   '계정',
#   '로그인',
#   '팝업',
#   '처음',
#   '페이지',
#   '아가',
#   '로그인'],
#  ['내용',
#   '이나',
#   '기술',
#   '로나',
#   '증권',
#   '베타',
#   '버전',
#   '던데',
#   '부터',
#   '제대로',
#   '어보',
#   '반적',
#   '개선'],
#  ['답답',
#   '인증',
#   '인증',
#   '비번',
#   '입력',
#   '카드',
#   '정보',
#   '오류',
#   '카드',
#   '발급',
#   '한참',
#   '다리',
#   '드디어',
#   '결제',
#   '방법',
#   '사람',
#   '볶음',
#   '똑바로'],
#  ['다운', '대기', '와이파이', '데이터', '모두', '아지', '이상하'],
#  ['단말기', '변경', '본인인증', '미성년', '로그인', '주민등록증', '운전면허증'],
#  ['투자',
#   '관련',
#   '불편',
#   '펀드',
#   '투자',
#   '아들',
#   '투자',
#   '이나',
#   '증권',
#   '투자',
#   '관련',
#   '메뉴',
#   '스텀',
#   '조속',
#   '수정',
#   '바람',
#   '솔직',
#   '펀드',
#   '몇개',
#   '검색',
#   '안해',
#   '뭥미'],
#  ['업뎃',
#   '이후',
#   '투자',
#   '중인',
#   '펀드',
#   '수가',
#   '투자',
#   '버튼',
#   '바로',
#   '버튼',
#   '주식',
#   '버튼',
#   '진심',
#   '화가',
#   '거지',
#   '업뎃'],
#  ['위젯', '멤버십', '바코드', '크기', '스캔', '매번', '실행', '위젯', '의미'],
#  ['알람', '부분', '도저히', '알람', '조만간', '카드', '고려', '중이', '그동안'],
#  ['새마을금고', '연동', '주식', '계좌', '업데이트', '지출', '필터', '관리', '어플'],
#  ['주식', '생기', '투자', '사라', '설정', '설정'],
#  ['라이언', '마네', '본적', '주식', '선물', '선물', '아야'],
#  ['뭔가', '부족', '주식', '마다', '기준', '금액', '정해', '한눈'],
#  ['충전', '버튼', '안보', '이전', '직관', '간단', '편리', '차이'],
#  ['내야',
#   '만원',
#   '전하라',
#   '효율',
#   '시스템',
#   '여진',
#   '이자',
#   '놀이',
#   '신지',
#   '답답',
#   '점점',
#   '이용자',
#   '한국',
#   '수시',
#   '노리',
#   '운영',
#   '옛날',
#   '언제',
#   '실행',
#   '띠딩',
#   '소리',
#   '심장',
#   '알림',
#   '음량',
#   '이나',
#   '미디어',
#   '음량',
#   '벨소리',
#   '음량',
#   '적막',
#   '도서관',
#   '화장실',
#   '기차',
#   '직장',
#   '민망',
#   '경험',
#   '방심',
#   '심장',
#   '튀어',
#   '처럼',
#   '놀란',
#   '절로',
#   '암만',
#   '설정',
#   '어보',
#   '고객',
#   '센터',
#   '정신',
#   '소리',
#   '최소한',
#   '기본',
#   '설정',
#   '뱅킹',
#   '여러분',
#   '구경',
#   '고하',
#   '출금',
#   '용도',
#   '비프',
#   '음량',
#   '거슬',
#   '리지'],
#  ['어제', '업데이트', '증귄', '서비스', '종료', '오류', '발생', '업데이트'],
#  ['답답',
#   '안전',
#   '인증인가',
#   '주민등록증',
#   '인증',
#   '하래',
#   '주민등록증',
#   '송금',
#   '카드',
#   '주민등록증',
#   '이나',
#   '운전면허증',
#   '번호',
#   '입력',
#   '하든',
#   '오륜가',
#   '이나',
#   '서도'],
#  ['증권',
#   '계좌',
#   '버킷리스트',
#   '입금',
#   '출금',
#   '조회',
#   '일주일',
#   '마다',
#   '자동',
#   '저축',
#   '계좌',
#   '해지',
#   '버킷리스트',
#   '해지'],
#  ['별안간', '화면', '인증', '문제', '핸드폰', '이나', '계좌', '인증'],
#  ['군인',
#   '카메라',
#   '제한',
#   '카드',
#   '등록',
#   '카메라',
#   '로만',
#   '스캔',
#   '직접',
#   '입력',
#   '군인',
#   '카메라',
#   '제한',
#   '수도',
#   '카드',
#   '등록',
#   '직접',
#   '입력'],
#  ['미성년', '본인인증', '신분증', '오늘', '전하', '인증', '하래', '신분증', '짜증'],
#  ['기본',
#   '보안',
#   '설정',
#   '얼굴인식',
#   '종이',
#   '여서',
#   '지문',
#   '인식',
#   '송금',
#   '얼굴인식',
#   '인증',
#   '덕분',
#   '시간'],
#  ['기본',
#   '책정',
#   '기사',
#   '절때',
#   '금액',
#   '기사',
#   '거리',
#   '대기',
#   '어이',
#   '리콜',
#   '이나',
#   '대리',
#   '기사',
#   '바로',
#   '금액',
#   '정확',
#   '사기',
#   '안당',
#   '참고'],
#  ['전하', '려면', '최소', '금액', '이상인', '불편', '오천', '정도', '최소', '충전', '금액'],
#  ['본인인증',
#   '주민등록증',
#   '시간',
#   '발급',
#   '상황',
#   '상황',
#   '발급',
#   '아야',
#   '안타',
#   '시기',
#   '고생',
#   '방법',
#   '을지',
#   '조심'],
#  ['계좌', '결하', '분동', '와이파이', '문제', '다리', '대포통장', '상태', '처음', '좀더'],
#  ['주민등록증',
#   '인증',
#   '어도',
#   '두운',
#   '배경',
#   '반사',
#   '최소한',
#   '주민등록증',
#   '날짜',
#   '수기',
#   '입력',
#   '게라',
#   '아침',
#   '부터',
#   '사람'],
#  ['여기',
#   '리뷰',
#   '처음',
#   '복잡',
#   '복잡',
#   '정도',
#   '스트레스',
#   '연결고리',
#   '이용자',
#   '아야',
#   '메뉴얼',
#   '비교'],
#  ['본인인증', '통신사', '성공', '이번', '횟수', '초과', '심지어', '분지', '초과', '관리', '이따', '위로'],
#  ['현재', '안드로이드', '충전', '오류', '앱재', '실행', '제대로', '불편'],
#  ['제발', '처럼', '주식', '결제', '크롤', '문하', '간편', '른데', '반응속도', '이탈'],
#  ['친구', '결하', '카운터', '자동', '대결', '상관', '짜증'],
#  ['장시',
#   '작전',
#   '분동',
#   '정보',
#   '누락',
#   '자주',
#   '발생',
#   '짜증',
#   '지경',
#   '중요',
#   '정보',
#   '실시간',
#   '반영',
#   '정도'],
#  ['난하', '도아', '계좌', '도입', '입금자', '입력', '입력', '글자', '입금자', '접속'],
#  ['정확', '맘대로', '사라', '려면', '가야', '그동안', '음수'],
#  ['폰트', '사이즈', '증권', '작동', '증권', '부분', '개발자'],
#  ['최근',
#   '핸드폰',
#   '초기',
#   '화해',
#   '로그인',
#   '본인인증',
#   '계좌',
#   '인증',
#   '고하',
#   '계좌번호',
#   '증권',
#   '로써',
#   '평소',
#   '라서',
#   '해결',
#   '해주시',
#   '감사'],
#  ['교하면', '혜택', '주식', '먹튀', '주가', '지고', '이미지', '회복', '려면', '혜택'],
#  ['주식', '볼때', '본적', '캔들', '차트', '만약', '설정', '직관', '보이', '로서', '부족'],
#  ['카드',
#   '고객',
#   '센터',
#   '문의',
#   '기면',
#   '답변',
#   '전화',
#   '문의',
#   '전화',
#   '시간',
#   '시간',
#   '지나',
#   '전화',
#   '연결',
#   '사용자',
#   '농락'],
#  ['업데이트', '버킷리스트', '버킷리스트', '메뉴', '만원', '증발'],
#  ['본인인증', '인증', '초과', '정부', '장금', '해제', '주민등록번호', '인증'],
#  ['휴대폰', '개인', '이용자', '이동', '도록', '중국', '서비스', '구리'],
#  ['본인인증',
#   '해달',
#   '주민등록증',
#   '이나',
#   '운전면허증',
#   '본인인증',
#   '아직',
#   '주민등록증',
#   '발급',
#   '애초',
#   '주민등록증',
#   '발급',
#   '다운',
#   '당장',
#   '발급',
#   '등록'],
#  ['로그인', '유지', '로그아웃', '본인인증', '고해', '정보', '알맟', '입력', '만하'],
#  ['송금', '서비스', '중인', '서비스', '구동', '개선'],
#  ['로그인', '계정', '로그인', '로그인', '계정', '로그인', '려면', '리뷰', '답장', '해주시'],
#  ['매우', '용량', '차지', '차라리', '삼성', '엘지', '구글', '매우', '매우'],
#  ['사용자',
#   '환경',
#   '직관',
#   '솔직',
#   '증권',
#   '뭔가',
#   '기적',
#   '기대',
#   '느낌',
#   '솔직',
#   '미니',
#   '스탁보',
#   '다도',
#   '디자인',
#   '이나',
#   '사용자',
#   '환경',
#   '직관',
#   '이지',
#   '군더더기',
#   '느낌',
#   '굳이',
#   '주식',
#   '투자자',
#   '기존',
#   '증권',
#   '어플',
#   '이동해',
#   '메리트',
#   '지지',
#   '국민',
#   '눈높이',
#   '사용자',
#   '환경',
#   '반적',
#   '개선',
#   '인적',
#   '처럼',
#   '직관',
#   '이면',
#   '소액',
#   '주주',
#   '진심',
#   '개선'],
#  ['일전', '신분증', '인증', '미성년', '인증'],
#  ['국방',
#   '모바일',
#   '보안',
#   '수도',
#   '카드',
#   '신규',
#   '등록',
#   '불가능',
#   '카드',
#   '번호',
#   '직접',
#   '입력',
#   '수가'],
#  ['주식',
#   '지정',
#   '매도',
#   '주문',
#   '당일',
#   '도하',
#   '마감',
#   '다음',
#   '매도',
#   '주문',
#   '불편',
#   '지정',
#   '매도',
#   '주문',
#   '당일',
#   '도하',
#   '다음',
#   '그다음',
#   '자동',
#   '매도',
#   '주문',
#   '개선',
#   '부탁',
#   '드립'],
#  ['신분증', '인증', '반사', '도록', '신분증', '번쩍', '거리', '계좌', '개설'],
#  ['주식', '어플', '다오', '먹통', '기본'],
#  ['미성년', '계좌', '계좌', '인증'],
#  ['미니', '금고', '경로', '불편'],
#  ['스탬프',
#   '이벤트',
#   '주식',
#   '당첨',
#   '가입',
#   '도하',
#   '막상',
#   '가입',
#   '가보',
#   '고객',
#   '만하',
#   '방식',
#   '가지가지'],
#  ['과거', '번호', '어플', '번호', '로그인', '불가능', '관계', '기변', '경후', '오기', '행위', '어찌'],
#  ['구글',
# ...
#   '보고',
#   '시급',
#   '오류',
#   '수정'],
#  ['주식',
#   '신뢰',
#   '의심',
#   '고객',
#   '대응',
#   '무책임',
#   '의경',
#   '매수',
#   '순간',
#   '기도',
#   '종목',
#   '수익률',
#   '순간',
#   '해임',
#   '불구',
#   '도하',
#   '반대',
#   '수익',
#   '도도',
#   '불구',
#   '수익',
#   '매도',
#   '고객',
#   '센터',
#   '어보',
#   '오류로',
#   '매도',
#   '매수',
#   '사용자',
#   '책임',
#   '사용자',
#   '거래',
#   '마다',
#   '평단',
#   '수익률',
#   '일일이',
#   '계산',
#   '거래'],
#  ['로그인',
#   '이후',
#   '인증',
#   '번호',
#   '주민',
#   '등록',
#   '번호',
#   '계좌',
#   '번호',
#   '고요',
#   '증권',
#   '계좌번호',
#   '연결',
#   '연결',
#   '계좌',
#   '자동',
#   '이체',
#   '닌지',
#   '불안',
#   '통장',
#   '이체',
#   '증권',
#   '관련',
#   '주소',
#   '모두',
#   '증권',
#   '증권',
#   '관련',
#   '처음',
#   '로그인',
#   '때시',
#   '계정',
#   '로그인',
#   '그다음',
#   '계좌번호',
#   '주민',
#   '번호',
#   '계좌',
#   '비번',
#   '기입',
#   '안내',
#   '증권',
#   '자동',
#   '이체',
#   '날짜',
#   '던데',
#   '불안'],
#  ['미성년', '자인', '민증', '이나', '면허증', '사진', '어케찍으', '마전'],
#  ['계정',
#   '지당',
#   '탈퇴',
#   '계정',
#   '교통카드',
#   '환불',
#   '환불',
#   '계정',
#   '정지',
#   '라서',
#   '로그인',
#   '불편',
#   '죄송',
#   '제대로',
#   '해결',
#   '탈퇴'],
#  ['요즘',
#   '보유',
#   '종목',
#   '등락',
#   '변동',
#   '엉망',
#   '실시간',
#   '모자',
#   '요지부동',
#   '재산',
#   '주식',
#   '선물',
#   '내기',
#   '아이콘',
#   '마이너스',
#   '계좌',
#   '선물',
#   '선물'],
#  ['신분증', '인식', '운전면허', '민증', '인식'],
#  ['쇼핑',
#   '결제',
#   '쇼핑',
#   '사이트',
#   '인터넷',
#   '결제',
#   '튕겨',
#   '삼성',
#   '인터넷',
#   '이니스프리',
#   '결제',
#   '이나',
#   '이니스프리'],
#  ['바탕', '이틀', '안내', '문자', '내야', '닌지'],
#  ['충전', '업뎃', '싢어', '지네'],
#  ['세미', '불편', '최대한', '년생', '부터'],
#  ['업데이트', '상당', '불편'],
#  ['증권', '개선', '시급', '난잡', '어려움'],
#  ['주민등록', '번호', '어도', '버튼', '활성화'],
#  ['결제', '에러', '결제', '네트워크', '오류'],
#  ['오늘', '접속', '짜증', '소액'],
#  ['계좌', '개발자', '만드'],
#  ['설치', '주식', '가끔', '이후', '주식', '스팸문자', '우연', '일치', '주식', '문자', '어플'],
#  ['학생', '어어', '결제', '문제', '취소'],
#  ['불편', '업데이트'],
#  ['펀드', '해지', '지하', '무조건', '해지', '더러'],
#  ['인증', '불가', '수가', '인증', '본인인증', '문의', '중인', '누가', '해결', '해주시'],
#  ['스레기', '수준', '경쟁'],
#  ['계정',
#   '인증',
#   '절차',
#   '복잡',
#   '인증',
#   '절차',
#   '무한',
#   '반복',
#   '제대로',
#   '휴대폰',
#   '인증',
#   '계정',
#   '비번',
#   '인증',
#   '권한',
#   '인증',
#   '실패',
#   '페이지',
#   '오류',
#   '터치',
#   '오류',
#   '기하',
#   '대체',
#   '화가'],
#  ['업뎃', '이후', '사용자', '누구', '아디', '온건', '미니', '금고', '수가', '당장', '개선'],
#  ['본인', '절차', '이후', '주민등록증', '이나', '운전면허증', '학생'],
#  ['체크카드', '분실', '재발', '고하', '에쓰', '번호', '그거', '번호', '인증', '해해', '결하'],
#  ['업데이트', '이후', '접촉', '불량', '연결상태', '문구'],
#  ['작동', '안함'],
#  ['종합', '계좌번호', '당장', '개선', '계좌번호', '전혀', '직관', '이지'],
#  ['대체', '언제', '적오', '로그인'],
#  ['휴먼', '계정', '비번', '설정', '휴먼', '계정'],
#  ['오류', '데브', '지나', '공지', '금융', '기관', '이란', '평일', '오류', '오늘', '그나', '주말'],
#  ['주식', '선물', '로그인', '애러', '코드', '수정', '언제', '고치'],
#  ['업데이트', '취소'],
#  ['사용자', '정보', '리다', '가입', '조차', '명의', '중인', '결제'],
#  ['본인', '인증', '수단', '민증', '정보', '바르게', '입력', '이나', '신분증', '정보', '오류'],
#  ['이나', '설치', '중인'],
#  ['분명',
#   '미자',
#   '신분증',
#   '이도',
#   '편리',
#   '신분증',
#   '인증',
#   '플레이스토어',
#   '어플',
#   '환불',
#   '그거',
#   '계좌',
#   '송금',
#   '스트레스'],
#  ['신분증', '인식', '기술', '가지', '신분증', '신분증', '인식', '주식', '신뢰'],
#  ['업데이트', '이후', '청소년', '인증', '방법', '민증', '면허', '일이'],
#  ['비밀번호', '등록', '로그인', '등록'],
#  ['자동'],
#  ['최악', '오늘', '잔고', '결재', '멋대로', '고요', '환불', '요청', '려면', '결재', '오류'],
#  ['어플'],
#  ['인증', '거기', '어플', '속도', '비트', '관련', '부분', '여러'],
#  ['불편',
#   '과연',
#   '누가',
#   '결제',
#   '계정',
#   '누가',
#   '상담사',
#   '해지',
#   '부탁',
#   '여러분',
#   '불편',
#   '전화',
#   '사람',
#   '인걸',
#   '인지',
#   '아야',
#   '제발',
#   '부탁',
#   '불편',
#   '사진'],
#  ['주식', '접속', '어쩌잔건', '오전'],
#  ['로그인', '화면', '반복', '로그인'],
#  ['빠젔구', '거래', '역도', '환불', '부탁', '드릴', '난하', '거도', '인지'],
#  ['본인',
#   '정보',
#   '업데이트',
#   '실행',
#   '학생',
#   '체크',
#   '불구',
#   '본인인증',
#   '주민등록증',
#   '운전면허증',
#   '요구',
#   '상황'],
#  ['분명', '신분증', '신분증', '안함'],
#  ['본인인증', '학생', '신분', '인증', '주민등록증', '이나', '운전면허증', '인증', '학생', '아직'],
#  ['중인', '서버', '증설', '필요', '자주', '먹통'],
#  ['본인인증',
#   '관련',
#   '질문',
#   '어케',
#   '본인인증',
#   '방법',
#   '민증',
#   '운전면허증',
#   '인걸',
#   '인증',
#   '수가',
#   '지경',
#   '인증'],
#  ['엉망',
#   '구매',
#   '판매',
#   '현재',
#   '거래',
#   '가가',
#   '매수',
#   '현재',
#   '매도',
#   '거래',
#   '설정',
#   '언제',
#   '정합',
#   '국내',
#   '주식',
#   '가창',
#   '제대로',
#   '해외',
#   '주식',
#   '호가',
#   '보이',
#   '수정',
#   '생각',
#   '개판'],
#  ['주민등록증', '아직', '발급', '운전면허', '고요', '나인', '인증'],
#  ['펀드', '자주'],
#  ['화면', '로그인', '패턴', '로그인'],
#  ['워드', '서비스', '중지', '별로', '지지도', '가불', '렀네'],
#  ['연결상태'],
#  ['수박',
#   '옛날',
#   '계정',
#   '뭌였길',
#   '탈퇴',
#   '는걸',
#   '본인인증',
#   '실패',
#   '카드',
#   '정보',
#   '치하',
#   '영수증',
#   '취소'],
#  ['미성년',
#   '차단',
#   '미만',
#   '일부',
#   '서비스',
#   '제한',
#   '민증',
#   '인증',
#   '세인',
#   '민증',
#   '아직',
#   '모든',
#   '서비스',
#   '불가능'],
#  ['청소년증', '인증', '가입', '놨던거', '탈퇴', '인증'],
#  ['학생', '신분증'],
#  ['여서', '미니', '미니', '등록', '고요', '결제', '수단', '특별', '미니'],
#  ['얼떨결',
#   '주식',
#   '펀드',
#   '가입',
#   '입하',
#   '자마자',
#   '듯이',
#   '주식',
#   '관련',
#   '투자',
#   '관련',
#   '문자',
#   '하루'],
#  ['지문',
#   '정보',
#   '변경',
#   '송금',
#   '비밀번호',
#   '자리',
#   '생각',
#   '비번',
#   '설정',
#   '온갖',
#   '인증',
#   '자리',
#   '비밀번호',
#   '입력',
#   '비밀번호',
#   '생각',
#   '고요',
#   '비밀번호',
#   '생각',
#   '비밀번호',
#   '설정'],
#  ['거래', '화면', '바로', '안보', '어플', '쓰기'],
#  ['교통카드', '완전', '불량', '스타', '카드'],
#  ['펀드', '중이', '었는데', '안보', '얼마나', '안보'],
#  ['생일',
#   '선물',
#   '노트북',
#   '포기',
#   '용돈',
#   '엄마',
#   '본인인증',
#   '하래',
#   '심지어',
#   '주민등록증',
#   '아직',
#   '발급',
#   '왜그',
#   '러시',
#   '본인인증',
#   '어도',
#   '금방',
#   '인생',
#   '맘대로'],
#  ['불편', '고하', '아직', '수두', '룩함', '심지어', '홈플러스', '고하'],
#  ['평상시', '지갑', '연결', '카드', '카드', '불가'],
#  ['처럼', '아이', '업데이트', '부탁', '드립', '아이', '어린이', '카드', '업데이트', '부탁', '드림', '제발'],
#  ['개발자', '어플', '탈퇴', '고객', '센터', '전화번호'],
#  ['거지', '아치', '거지', '처럼', '설명', '수도'],
#  ['업데이트', '조차', '주가', '폭락'],
#  ['위젯',
#   '결제',
#   '바로가기',
#   '설정',
#   '카드',
#   '위젯',
#   '결제',
#   '버튼',
#   '그게',
#   '제일',
#   '튀어',
#   '나오니',
#   '불편',
#   '개선'],
#  ['이건', '인증', '로그인', '결재'],
#  ['본인인증', '지네', '설치', '여전'],
#  ['송금', '무료', '뭔가', '요즘', '본적', '송금', '무료'],
#  ['자동', '투자', '회하', '수익률', '점점', '무거워', '이참', '손절'],
#  ['고하', '기존', '해지', '고하'],
#  ['업데이트', '안달', '라지', '업뎃', '쓰레기'],
#  ['아직',
#   '민증',
#   '발급',
#   '로그인',
#   '풀어버',
#   '리더',
#   '본인인증',
#   '기면',
#   '튕겨낼거',
#   '아주',
#   '지나',
#   '카드',
#   '고요',
#   '미리',
#   '안내',
#   '종료',
#   '고요',
#   '관련',
#   '처리',
#   '리리',
#   '훨신',
#   '포인트',
#   '이주',
#   '수수료'],
#  ['증권', '오류', '언제', '고치', '아야'],
#  ['주식', '거래', '오류', '시외', '거래'],
#  ['업데이트',
#   '미성년',
#   '자도',
#   '주민등록증',
#   '이나',
#   '주민등록',
#   '등본',
#   '운전면허증',
#   '미성년',
#   '이지',
#   '대학생',
#   '필요',
#   '조치',
#   '부탁',
#   '드립'],
#  ['펀드',
#   '자동',
#   '투자',
#   '백만',
#   '처음',
#   '펀드',
#   '광고',
#   '투자',
#   '가게',
#   '꽁꽁',
#   '펀드',
#   '포함',
#   '짜증',
#   '오조',
#   '오억',
#   '개발자',
#   '전문가',
#   '정작',
#   '개발자',
#   '비전문가'],
#  ['레이', '이벤트', '제주', '반응', '클레', '이벤트', '참여'],
#  ['카메라', '초첨', '계좌', '최초', '실패'],
#  ['업데이트', '노란색', '화면', '제거', '아야'],
#  ['대체', '언제', '잘못', '입금', '정보', '아지'],
#  [],
#  ['가끔', '카드', '기본', '결제', '설정', '심결', '출금', '현금', '결제', '짜증'],
#  ['송금', '수가', '도둑'],
#  ['업데이트', '자동', '유도'],
#  ['미자', '계좌', '연결', '선불', '충전'],
#  ['투자', '현황', '진입'],
#  ['해외', '주식', '지정', '가도', '금액', '매수', '매도', '수량'],
#  ['업데이트',
#   '누구',
#   '대기업',
#   '지우',
#   '겨자',
#   '먹기',
#   '종합',
#   '관리',
#   '정작',
#   '충전',
#   '서하',
#   '인지',
#   '인지',
#   '증권사',
#   '인지',
#   '어플',
#   '누지',
#   '하나로',
#   '충전',
#   '간겁'],
#  ['어제', '부터', '접속', '이건', '고객', '센터', '수가', '증권'],
#  ['구글', '기프트', '코드', '매하', '잘못', '가기', '구매', '구매', '처리', '오늘', '해결'],
#  ['스탬프', '이벤트', '참여', '중인', '사라', '마지막', '스탬프', '상태', '사라'],
#  ['신분증', '인식', '처음', '직접', '게라'],
#  ['어플', '새끼'],
#  [],
#  ['학생', '주민등록증', '본인인증', '운전면허증', '이나', '주민등록증', '본인인증', '학생', '본인인증'],
#  ['실행',
#   '고객',
#   '단말',
#   '해킹',
#   '위험성',
#   '탐지',
#   '인지도',
#   '재부팅',
#   '사라',
#   '갤럭시',
#   '디바이스',
#   '보호',
#   '검사',
#   '문제',
#   '발견',
#   '플레이스토어',
#   '설치',
#   '불안감',
#   '조성',
#   '인지',
#   '단순',
#   '오류'],
#  ['전부', '여서', '살인', '수도', '불편', '세도'],
#  ['비트', '입출금', '신청', '인증', '고하', '튕깁니', '오늘', '부터'],
#  ['영수증',
#   '캡쳐',
#   '려면',
#   '최신',
#   '버전',
#   '요하',
#   '고해',
#   '전부',
#   '최신',
#   '버전',
#   '업데이트',
#   '최신',
#   '버전',
#   '요하'],
#  ['미성년', '본인', '민증', '면허증', '송금'],
#  ['오류', '특이', '인증', '오류'],
#  ['미성년', '자도', '부탁', '만큼', '처럼', '미성년', '억울', '미성년', '요즘', '기분'],
#  ['지문', '완료'],
#  ['상품권', '전환', '온라인', '수도', '오프라인', '불편'],
#  ['학생',
#   '용돈',
#   '저금',
#   '오늘',
#   '인증',
#   '음으로',
#   '인증',
#   '인증',
#   '수단',
#   '주민등록증',
#   '운전면허증',
#   '가지',
#   '민증',
#   '미성년',
#   '자인',
#   '로그인',
#   '조차',
#   '수도',
#   '문의',
#   '여기'],
#  ['민증', '아직', '민증', '인증'],
#  ['아직', '민증', '미성년', '가입', '해결', '마련'],
#  ['거래',
#   '대금',
#   '안보',
#   '미국',
#   '주식',
#   '거래',
#   '수수료',
#   '미국',
#   '주식',
#   '거래',
#   '체결',
#   '리다',
#   '연동',
#   '증권',
#   '덕분',
#   '만원',
#   '이번',
#   '출금',
#   '증권',
#   '유도',
#   '신들',
#   '악마'],
#  ['현재', '오류', '접속', '주식', '리하', '대로', '증권'],
#  ['처음', '걸음', '측정', '다음', '부터', '첫날', '음수'],
#  ['연동', '반드시', '카페', '완전', '짜증', '짜증', '짜증', '짜증'],
#  ['겔럭시', '이안', '이안'],
#  ['모바일', '교통카드', '모바일', '교통카드'],
#  ['미성년',
#   '자인',
#   '순간',
#   '본인인증',
#   '절차',
#   '진행',
#   '민증',
#   '운전면허증',
#   '여권',
#   '거나',
#   '처음',
#   '부터',
#   '미성년',
#   '미성년',
#   '대적',
#   '홍보',
#   '입출금',
#   '모조리',
#   '아버',
#   '덕분'],
#  ['만원', '이하', '충전'],
#  ['컬쳐', '캐쉬', '캐쉬', '사려'],
#  ['충전', '메뉴'],
#  ['자동', '겔제', '적용', '구글', '결제'],
#  ['별도',
#   '출시',
#   '모바일',
#   '결제',
#   '려면',
#   '실행',
#   '독립성',
#   '별도',
#   '상장',
#   '사가',
#   '임원',
#   '위해',
#   '별도',
#   '상장',
#   '실행',
#   '도록',
#   '존재',
#   '뭔가'],
#  ['이번',
#   '일이',
#   '오류로',
#   '접근',
#   '는걸',
#   '증권사',
#   '조회',
#   '버퍼',
#   '미니',
#   '금고',
#   '에러',
#   '번은',
#   '게걸',
#   '린거',
#   '송금',
#   '평가'],
#  ['입금', '계좌번호', '라서', '입금', '계좌번호'],
#  ['하자',
#   '얼마',
#   '본인인증',
#   '민증',
#   '민증',
#   '인증',
#   '묶인',
#   '만원',
#   '민증',
#   '간편',
#   '결제',
#   '어이',
#   '민증',
#   '내년',
#   '어도',
#   '는걸',
#   '어이',
#   '고요',
#   '하자',
#   '민증',
#   '본인인증',
#   '시스템',
#   '여태',
#   '하루아침',
#   '생각'],
#  ['지난번', '처럼', '호가', '사고', '퍼센트', '증권', '보구', '불편', '주식', '팔면', '증권사'],
#  ['미성년', '인증', '업데이트', '인지', '생일', '선물', '결제', '최악'],
#  ['교통카드', '문제'],
#  ['업데이트', '도안', '도안'],
#  ['미성년',
#   '자라',
#   '여태',
#   '군가',
#   '주민등록',
#   '발급',
#   '난하',
#   '고요',
#   '실패',
#   '잠기',
#   '친구',
#   '문의',
#   '발급',
#   '인증',
#   '곳도',
#   '어이'],
#  ['시간', '접속'],
#  ['계정', '여러', '아이디', '여러', '계정'],
#  ['금액', '충전', '충전'],
#  ['계정', '연동', '인증번호', '화면'],
#  ['아고다', '할인', '혜택', '전혀', '제공', '혜택', '분할', '부터', '오감', '생기'],
#  ['오늘', '주식', '버벅거려', '덕분', '증권사', '어플'],
#  ['주민등록증'],
#  ['카드결제', '우선', '순위', '카드', '포인트', '현금', '결제', '우선', '순위'],
#  ['미니', '금고', '입출금', '물어', '물어', '방법'],
#  ['웃기', '이벤트', '처럼', '광고', '친구', '초대', '사용자', '스팸', '마케팅', '카겜'],
#  ['오류'],
#  ['미니', '계좌연결', '연결', '려면', '미니', '미니', '계좌연결', '미니카', '수령', '해결'],
#  ['휴먼', '계정'],
#  ['갈수록', '불편', '해지', '뜬금'],
#  ['불친절', '고인'],
#  ['혜택', '이벤트', '혜택'],
#  ['에러', '심해', '개발', '제대로'],
#  ['언제', '복구', '안내', '문자', '황당', '법적', '문제'],
#  ['고객', '센터', '문의', '답변'],
#  ['주민', '득록증', '어캐', '민증', '발급', '기간', '입력'],
#  ['주식',
#   '판매',
#   '언제',
#   '입금',
#   '설명',
#   '그거',
#   '대한',
#   '설명',
#   '판매',
#   '완료',
#   '증발',
#   '판매',
#   '금액',
#   '설정',
#   '거도',
#   '불편',
#   '한참',
#   '헤메',
#   '겨우',
#   '설정',
#   '펀드',
#   '투자',
#   '린다',
#   '설명',
#   '여기',
#   '보이지'],
#  ['정지', '결제', '비번', '스트레스'],
#  ['안녕', '비밀번호', '인증', '래서', '비밀번호', '계좌', '인증'],
#  ['아직', '주민등록증', '발급', '인증', '이건'],
#  ['주식',
#   '내주',
#   '항목',
#   '정렬',
#   '금액',
#   '주식',
#   '구매',
#   '판매',
#   '판매',
#   '손익',
#   '종목',
#   '나니',
#   '동일',
#   '조건',
#   '주문',
#   '지하도',
#   '기간',
#   '설정',
#   '어제'],
#  ['카드', '만들기', '사진', '스텝', '가면', '미션', '나잇', '에러', '테스트', '퍼블리시'],
#  ['스플래시', '화면', '음으로'],
#  ['가입',
#   '계정',
#   '로그인',
#   '계정',
#   '로그인',
#   '가입',
#   '계정',
#   '탈퇴',
#   '가입',
#   '로그인',
#   '가입',
#   '계정',
#   '뫼비우스'],
#  ['문의', '자기', '부분', '거지'],
#  ['주식', '대금', '해외', '주식', '팘았는데', '야금', '야금', '지네', '안남'],
#  ['펀드', '서비스', '시작', '코로나', '떡락', '주식', '서비스', '시작', '시점'],
#  ['요새', '접속'],
#  ['안녕', '며칠', '프로필', '계명', '이름', '로그인', '돼지', '옜날', '이름', '이름', '로그인'],
#  ['오류', '계약금', '내야', '오늘', '입금', '계약위반', '계약금', '하실껀데'],
#  ['문제', '본인인증', '계정', '연결', '로그인', '계정', '로그인', '할라카', '본인인증'],
#  ['금액', '이상', '오류', '만원', '송금', '알리', '워드', '원인'],
#  ['이용자',
#   '차별',
#   '아이폰',
#   '이건',
#   '차별',
#   '답변',
#   '보아',
#   '차별금지법',
#   '양반',
#   '아이폰',
#   '차별',
#   '삼성'],
#  ['만원', '충전', '천원', '만원', '단위', '천원', '이천원', '제하', '만원'],
#  ['결재', '시스템', '결재', '서비스', '운영'],
#  ['펀드', '해당', '금액', '전부', '아야'],
#  ['맥북', '불가능', '설치', '불가능'],
#  ['민증', '사람', '민증', '인증', '본인인증', '이후'],
#  ['이벤트',
#   '푸시',
#   '클릭',
#   '해당',
#   '이벤트',
#   '참여',
#   '방법',
#   '따위',
#   '글귀',
#   '무조건',
#   '설치',
#   '요하',
#   '요즘',
#   '사람',
#   '무조건',
#   '자신감'],
#  ['펀드', '투자', '중인', '보나', '메뉴', '펀드', '어쩌란거'],
#  ['미성년', '불편', '거기', '베스킨라빈스', '해결', '불편', '짜증'],
#  ['모바일', '교통카드'],
#  ['계좌', '인증', '요청', '횟수', '초과'],
#  ['카카오페이지', '금융', '기관', '등록', '신협', '신협', '제외', '기관', '등록'],
#  ['대출', '한도', '회하', '현재', '인프라', '점검', '중인', '금융', '사가', '언제', '복구'],
#  ['주식', '멤버십', '주식'],
#  ['만원', '미만', '결제', '강제', '만원', '충전', '완전', '짜증'],
#  ['서버', '낫다', '증권'],
#  ['카드', '서명', '변경', '카드', '서비스', '해지', '등록', '서비스', '해지'],
#  ['멜론', '이용권', '매하', '결제', '로그인', '주민등록증', '발급', '날짜', '입력', '아직', '주민등록증'],
#  ['본인인증', '고해', '발급', '일자', '리다'],
#  ['카카', '오주식', '주식', '타자', '커서', '이동', '오타', '가계', '주식', '가격', '변동', '반영'],
#  ['접속'],
#  ['다운로드', '대기', '부탁', '드립', '다운'],
#  ['카뱅', '계좌', '수수료', '자회사', '이자', '님들'],
#  ['주민등록증',
#   '발급',
#   '학생',
#   '생일',
#   '지나',
#   '서부',
#   '발급',
#   '일자',
#   '미니',
#   '거치',
#   '고서',
#   '기프티콘',
#   '상황',
#   '매우',
#   '매우',
#   '돈좀',
#   '제발'],
#  ['카드', '짜증', '해지'],
#  ['중인',
#   '계정',
#   '형식',
#   '계정',
#   '통합',
#   '유도',
#   '이건',
#   '로그인',
#   '불가',
#   '중인',
#   '계정',
#   '신뢰',
#   '다음',
#   '폐기',
#   '상황'],
#  ['휴대폰', '인증', '인증번호'],
#  ['계정', '로긘', '기존', '로긘'],
#  ['증권', '런가', '어플', '연결', '오류', '보상', '어플', '똑바로'],
#  ['금액', '주식', '사라', '금액', '더편', '하내', '호가', '금액', '사고', '팔고', '한참'],
#  ['불편',
#   '카드',
#   '통장',
#   '증원',
#   '투자',
#   '소비',
#   '분석',
#   '카카',
#   '권유',
#   '추천',
#   '자동',
#   '투자',
#   '증권',
#   '대기',
#   '하겟단건',
#   '보먄',
#   '짜증',
#   '카드',
#   '라거',
#   '할때마드',
#   '연결',
#   '카드',
#   '내용',
#   '볼때',
#   '마다',
#   '인증서',
#   '텅합',
#   '바로',
#   '페일'],
#  ['휴대폰', '계정', '계정', '서로', '동시', '로그인', '계정', '무조건', '아야'],
#  ['짜증',
#   '학생',
#   '민증',
#   '달라',
#   '삼성',
#   '미니카',
#   '드가있',
#   '어도',
#   '카드',
#   '결제',
#   '도안',
#   '설정',
#   '학생'],
#  ['팝콘', '콤보', '쿠폰', '팝콘', '개인', '논리', '쿠폰', '설명', '관련', '내용', '거기'],
#  ['아직', '민증', '발급', '민증'],
#  ['민증', '모하', '역시', '삼성', '빠따', '티어', '레전드', '결제', '수단', '미안', '기분'],
#  ['대표'],
#  ['결제'],
#  ['주식', '체결', '체결', '단가'],
#  ['미성년', '자인', '처음', '본인인증', '인증', '수단'],
#  ['이벤트', '참여', '친구', '내기', '화면', '먹통'],
#  ['로그인'],
#  ['갈수록', '불편', '해지'],
#  [],
#  ['업데이트'],
#  ['미성년', '자인', '본인인증', '주민등록증', '인증', '계좌', '아가'],
#  ['미성년', '본인인증', '민증', '어떡', '본인인증', '방법'],
#  ['본인', '아직', '학생', '주민등록증', '인지'],
#  ['인증', '던데', '증발', '급전', '인증', '남아'],
#  ['갤럭시', '지원', '애플', '던데'],
#  ['송금', '고요', '리뷰', '제하'],
#  ['스탬프', '인간', '스탬프', '이상', '사람', '현혹', '독점', '노력'],
#  ['갤럭시', '지원'],
#  ['여기', '만원', '벌써', '만원', '잘못', '청소년', '입장', '상당', '타격', '거좀', '해결'],
#  ['놓쳣네', '복구', '코레일', '결제', '공지'],
#  ['별하나', '다음', '프리미엄', '메일', '신청', '명단', '축하', '모두', '결제', '절차', '최악', '국민'],
#  [],
#  ['설치', '대기', '중인'],
#  ['걷기', '요금', '수이', '지아'],
#  ['고객',
#   '센터',
#   '전화',
#   '궁금증',
#   '먹기',
#   '안내',
#   '고객',
#   '센터',
#   '전화',
#   '아침',
#   '시부',
#   '오후',
#   '전화',
#   '통화량',
#   '연결'],
#  ['주식', '평가', '금액', '업데이트', '불편'],
#  ['제발', '신용정보', '변동', '알림', '플러스', '친구'],
#  ['경영', '먹튀', '개미', '님들'],
#  ['금액', '누락', '예금', '계좌', '금액', '여요', '중간', '숫자', '누락'],
#  ['로그인', '일도', '행복'],
#  ['매수', '매도', '매물', '대가', '안보', '주식', '어케합'],
#  ['주민등록증', '운전면허증', '인증', '청소년'],
#  ['공모', '알림', '신청', '해지'],
#  ['해지', '해지'],
#  ['언제', '생각', '신가'],
#  ['미성년', '본인', '거임', '운전면허', '주민등록증', '업데이트'],
#  ['어제', '교통카드'],
#  ['아직', '복구'],
#  ['로그인', '대로'],
#  ['실상', '요기', '결제', '연동'],
#  ['코드', '스캔', '구림'],
#  ['청구', '접속', '이안', '신경', '청구'],
#  ['분지',
#   '인증',
#   '계정',
#   '그거',
#   '햐지좀',
#   '아쌈',
#   '짓거리',
#   '간단',
#   '인등',
#   '유독',
#   '유난',
#   '집착',
#   '거의',
#   '수준',
#   '새벽',
#   '내내',
#   '포기',
#   '계정',
#   '로그인',
#   '계정',
#   '자동',
#   '탈퇴',
#   '철저',
#   '보안',
#   '연동',
#   '서비스',
#   '는걸',
#   '안보',
#   '계정',
#   '탈퇴',
#   '처리',
#   '카라',
#   '거임',
#   '이메일',
#   '사람',
#   '카라',
#   '진심'],
#  ['펀드', '관리', '기존', '펀드', '입금', '어도'],
#  ['쓰래', '신분증', '인식', '야사', '어우', '더러'],
#  [],
#  ['주말', '환전', '지나', '서하', '시지', '젠데'],
#  ['노란색', '화면', '안정', '한지', '주식', '예정'],
#  ['어플'],
#  ['증권', '화면'],
#  ['식이', '주식', '선물', '로그인', '약관', '동의', '주식', '계좌', '개설', '중이', '업데이트', '부탁'],
#  ['거래', '업데이트'],
#  ['투자', '중인', '펀드', '주식', '방법'],
#  ['교통카드', '결제'],
#  ['인증', '다음', '단계'],
#  ['구글플레이', '결제', '배너', '보고', '설치', '결제', '어케', '안내', '사항'],
#  ['보안', '던데'],
#  ['요즘', '접속'],
#  ['가오', '증권', '안보'],
#  ['최근', '렉'],
#  ['사람', '상담', '상담', '로봇', '대답'],
#  ['미장', '애프터', '마켓', '거래', '불가', '젠장'],
#  ['증권',
#   '익명',
#   '사람',
#   '전문가',
#   '이름',
#   '적극',
#   '매수',
#   '적극',
#   '매도',
#   '투자',
#   '의견',
#   '참고',
#   '게시',
#   '의도',
#   '달리',
#   '오히려',
#   '문제',
#   '소지',
#   '전문가',
#   '로서',
#   '투자',
#   '의견',
#   '게시',
#   '려면',
#   '소속',
#   '직책',
#   '해당',
#   '의견',
#   '시점',
#   '게시'],
#  [],
#  ['펀드', '펀드', '안보', '여요'],
#  ['발급', '일자', '초과', '정부', '해제', '답답', '방법'],
#  ['돈버', '게임', '현금화', '수가'],
#  ['학생', '민증', '발급', '날짜'],
#  ['관리', '불편', '증권', '정보', '부실'],
#  ['데이터'],
#  ['아가', '공지', '모니터링', '안해'],
#  ['결제', '게임'],
#  ['결제오류'],
#  [],
#  ['업데이트', '펀드'],
#  ['주민등록증', '인증'],
#  ['운전면허', '사람', '소리'],
#  ['짜증'],
#  ['가지', '이상'],
#  ['송금'],
#  ['미자', '본인인증', '해결'],
#  ['병원', '청구', '오류'],
#  ['주민등록증', '인증', '페이도', '선물', '기도'],
#  ['업데이트'],
#  ...]

# %%
from gensim.models.ldamodel import LdaModel
from gensim.models.callbacks import CoherenceMetric
from gensim import corpora
from gensim.models.callbacks import PerplexityMetric

# %%
dictionary = corpora.Dictionary(processed_data)

# %%
print(dictionary)
# Out:
# Dictionary<2563 unique tokens: ['고도', '노트', '디자인', '문제', '바코드']...>

# %%
dictionary.filter_extremes(no_below=5, no_above=0.5)

# %%
corpus = [dictionary.doc2bow(text) for text in processed_data]

# %%
len(processed_data)
# Out:
# 1357

# %%
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt 

def show_coherence(corpus, dictionary, start=4, end=15):
    iter_num=[]
    per_value=[]
    coh_value=[]
    
    for i in range(start, end+1):
        model=LdaModel(corpus=corpus, id2word=dictionary, num_topics=i)
        iter_num.append(i)
        pv=model.log_perplexity(corpus)
        per_value.append(pv)
        
        cm=CoherenceModel(model=model, corpus=corpus, coherence='u_mass')
        cv=cm.get_coherence()
        coh_value.append(cv)
        print(f'num_topics: {i}, perplexity: {pv:0.3f}, coherence: {cv:0.3f}')
    plt.figure(figsize=(30,30))
    plt.plot(iter_num, per_value, 'g-')
    plt.xlabel("num_topics",fontsize=40)
    plt.ylabel("perplexity",fontsize=40)
    plt.xticks(fontsize=40)
    plt.yticks(fontsize=40)
    plt.show()
    plt.figure(figsize=(30,30))
    plt.plot(iter_num, coh_value, 'r-')
    plt.xlabel("num_topics",fontsize=40)
    plt.ylabel("coherence",fontsize=40)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.show()

# %%
show_coherence(corpus, dictionary, start=6,end=15)

# 최적의 토픽의 수 결정하기 coherence가 높은 지점인 4로 토픽 수 정하기
# Out:
# num_topics: 6, perplexity: -6.262, coherence: -7.756
# num_topics: 7, perplexity: -6.342, coherence: -7.723
# num_topics: 8, perplexity: -6.401, coherence: -8.037
# num_topics: 9, perplexity: -6.435, coherence: -8.060
# num_topics: 10, perplexity: -6.477, coherence: -8.181
# num_topics: 11, perplexity: -6.490, coherence: -9.044
# num_topics: 12, perplexity: -6.566, coherence: -7.972
# num_topics: 13, perplexity: -6.604, coherence: -8.394
# num_topics: 14, perplexity: -6.652, coherence: -8.776
# num_topics: 15, perplexity: -6.693, coherence: -9.012

# %%
df
# Out:
#                  날짜                                                 리뷰  별점  \
# 0      2021년 2월 21일  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요... +)디자인에 문제가 아니라 바코...   2
# 1     2021년 10월 30일  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플....   3
# 3      2021년 5월 18일  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...   2
# 4       2021년 2월 9일  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요,,, 데이터도 쓰고 와이파...   1
# 5      2021년 2월 10일  위젯이 기존 모양이 아닌 갑자기 작아져서 나옵니다. 짤려서 나오구요. 여러가지 모양...   1
# ...             ...                                                ...  ..
# 1384   2023년 4월 12일                                  카카오페이 쉽게 탈하는법 없나요   1
# 1385   2023년 1월 12일                             미장 증권 개장했는데 나만 멈췄나여?ㅜㅠ   1
# 1386   2023년 3월 17일                                        충전하고 인출 오류남   1
# 1387   2023년 1월 20일                                      출석체크 왜 안되나요??   1
# 1388   2023년 9월 23일                                렉 걸리는거 절대 안고치네...ㄷㄷ   1
#
#           month                                                리뷰1  \
# 0    2021-02-01  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요 디자인에 문제가 아니라 바코드가 분에...
# 1    2021-10-01  국내에서 사용 가능한 모든 금융 관련 어플중에서 비밀번호 등록이 가장 어려운 어플 ...
# 3    2021-05-01  결제할 때 카드를 선택해놓고 시간이 지나서 폰 화면이 꺼졌을 때 다시 화면을 켜면 ...
# 4    2021-02-01  신규로 깔아서 해보려하는데 계속 연결상태가 좋지 않다네요 데이터도 쓰고 와이파이도 ...
# 5    2021-02-01  위젯이 기존 모양이 아닌 갑자기 작아져서 나옵니다 짤려서 나오구요 여러가지 모양 있...
# ...         ...                                                ...
# 1384 2023-04-01                                  카카오페이 쉽게 탈하는법 없나요
# 1385 2023-01-01                                미장 증권 개장했는데 나만 멈췄나여
# 1386 2023-03-01                                        충전하고 인출 오류남
# 1387 2023-01-01                                        출석체크 왜 안되나요
# 1388 2023-09-01                                     렉 걸리는거 절대 안고치네
#
#                                                     리뷰2         quarters
# 0     ['위젯', '짤려', '디자인', '문제', '바코드', '이나', '짤려', '...  2021-02~2021-04
# 1     ['국내', '모든', '금융', '관련', '어플', '비밀번호', '등록', '...  2021-08~2021-10
# 3     ['결제', '카드', '선택', '시간', '지나', '화면', '화면', '카드...  2021-05~2021-07
# 4     ['신규', '연결상태', '데이터', '와이파이', '데이터', '접속', '당장...  2021-02~2021-04
# 5     ['위젯', '기존', '모양', '짤려', '오구', '여러가지', '모양', '...  2021-02~2021-04
# ...                                                 ...              ...
# 1384                                                 []  2023-02~2023-04
# 1385                                 ['미장', '증권', '개장']  2022-11~2023-01
# 1386                                       ['충전', '오류']  2023-02~2023-04
# 1387                                       ['출석', '체크']  2022-11~2023-01
# 1388                                  ['렉', '절대', '고치']  2023-08~2023-10
#
# [1357 rows x 7 columns]

# %%
# 21년도 7월은 리뷰 글이 하나여서 뒤에 그래프 그릴 때 21년도 7월은 그리지 말기

import pandas as pd 

df_sorted=df.sort_values(by='quarters')        # 문서를 시작날짜 순으로 정렬
df_sorted
# Out:
#                 날짜                                                 리뷰  별점  \
# 0     2021년 2월 21일  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요... +)디자인에 문제가 아니라 바코...   2
# 133    2021년 3월 1일     순 자산이 업데이트가 계속 안 되네요... 업데이트 눌러도 27일 전에 멈춰 있어요   1
# 423   2021년 2월 28일                                 키움과 db증권 연결이 말썽이네요   1
# 294   2021년 3월 23일  특정문구누르면 어플종료되길래 재설치까지했는데 이젠 아예 로그인조차 안되네요 .. ㅡ...   1
# 293   2021년 3월 29일    계정으로 로그인 본인인증하면 이미 가입한 계정이 있다고 무한반복 ㅡㅡ 사람 빡치게하네   1
# ...            ...                                                ...  ..
# 1203  2023년 10월 6일                      4x2 멤버십 위젯이 아직도 잘려 나와요. 고쳐주세요   1
# 1212  2023년 10월 8일                            로그인 이 도대체 않돼요 어떻게 된겄입니까   1
# 1213  2023년 10월 8일                                   송금하는데화면이움지기고와따가함   2
# 1215  2023년 9월 23일                         아직사용은 안했는데 이제부터 사용하고 싶네요^^   3
# 1388  2023년 9월 23일                                렉 걸리는거 절대 안고치네...ㄷㄷ   1
#
#           month                                                리뷰1  \
# 0    2021-02-01  잘쓰고 있었는데 위젯이 갑자기 짤려서 나오네요 디자인에 문제가 아니라 바코드가 분에...
# 133  2021-03-01          순 자산이 업데이트가 계속 안 되네요 업데이트 눌러도 일 전에 멈춰 있어요
# 423  2021-02-01                                 키움과 DB증권 연결이 말썽이네요
# 294  2021-03-01  특정문구누르면 어플종료되길래 재설치까지했는데 이젠 아예 로그인조차 안되네요 카카오같...
# 293  2021-03-01       계정으로 로그인 본인인증하면 이미 가입한 계정이 있다고 무한반복 사람 빡치게하네
# ...         ...                                                ...
# 1203 2023-10-01                         X 멤버십 위젯이 아직도 잘려 나와요 고쳐주세요
# 1212 2023-10-01                            로그인 이 도대체 않돼요 어떻게 된겄입니까
# 1213 2023-10-01                                   송금하는데화면이움지기고와따가함
# 1215 2023-09-01                           아직사용은 안했는데 이제부터 사용하고 싶네요
# 1388 2023-09-01                                     렉 걸리는거 절대 안고치네
#
#                                                     리뷰2         quarters
# 0     ['위젯', '짤려', '디자인', '문제', '바코드', '이나', '짤려', '...  2021-02~2021-04
# 133                                    ['업데이트', '업데이트']  2021-02~2021-04
# 423                                  ['증권', '연결', '말썽']  2021-02~2021-04
# 294   ['특정', '문구', '어플', '종료', '설치', '로그인', '조차', '회...  2021-02~2021-04
# 293   ['계정', '로그인', '본인인증', '가입', '계정', '무한', '반복', ...  2021-02~2021-04
# ...                                                 ...              ...
# 1203                                ['멤버십', '위젯', '아직']  2023-08~2023-10
# 1212                                     ['로그인', '된겄입']  2023-08~2023-10
# 1213                                 ['송금', '화면', '지기']  2023-08~2023-10
# 1215                                       ['아직', '부터']  2023-08~2023-10
# 1388                                  ['렉', '절대', '고치']  2023-08~2023-10
#
# [1357 rows x 7 columns]

# %%
df_sorted['quarters'].value_counts().sort_index()
# Out:
# quarters
# 2021-02~2021-04    154
# 2021-05~2021-07    140
# 2021-08~2021-10    199
# 2021-11~2022-01    157
# 2022-02~2022-04    123
# 2022-05~2022-07     84
# 2022-08~2022-10    117
# 2022-11~2023-01     90
# 2023-02~2023-04     75
# 2023-05~2023-07    112
# 2023-08~2023-10    106
# Name: count, dtype: int64

# %%
# 월별로 문서가 몇 건인지를 계산하여 time_slice에 저장 

time_slice=df_sorted['quarters'].value_counts().sort_index()

print(time_slice, sum(time_slice))
# Out:
# quarters
# 2021-02~2021-04    154
# 2021-05~2021-07    140
# 2021-08~2021-10    199
# 2021-11~2022-01    157
# 2022-02~2022-04    123
# 2022-05~2022-07     84
# 2022-08~2022-10    117
# 2022-11~2023-01     90
# 2023-02~2023-04     75
# 2023-05~2023-07    112
# 2023-08~2023-10    106
# Name: count, dtype: int64 1357

# %%
pd.DataFrame(time_slice)['count'].to_list()
# Out:
# [154, 140, 199, 157, 123, 84, 117, 90, 75, 112, 106]

# %%
time_slice=pd.DataFrame(time_slice)['count'].to_list()
print(time_slice, sum(time_slice))
# Out:
# [154, 140, 199, 157, 123, 84, 117, 90, 75, 112, 106] 1357

# %%
# LdaSeqModel을 실행

from gensim.models import LdaSeqModel 
import warnings 
warnings.filterwarnings("ignore") 

# 시간이 많이 소요됨

ldaseq=LdaSeqModel(corpus=corpus, id2word=dictionary, time_slice=time_slice, num_topics=7,random_state=7)

# %%
## ldaseq 모델 저장하기

from gensim.test.utils import datapath
temp_file = datapath("C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/kakao_datafile/kakaomodel2.gensim")
ldaseq.save(temp_file)

# %%
from tqdm import tqdm

import re
from gensim.models.ldamodel import LdaModel
from gensim.models.callbacks import CoherenceMetric
from gensim import corpora
from gensim.models.callbacks import PerplexityMetric
from gensim.matutils import hellinger
from gensim.models import ldaseqmodel
import logging
import pickle
import pyLDAvis.gensim
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

# %%
## 저장한 Ldaseqmodel 불러오기

from gensim.test.utils import datapath

temp_file = datapath("C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/kakao_datafile/kakaomodel2.gensim")
ldaseq = ldaseqmodel.LdaSeqModel.load(temp_file)

# %%
for j in range(7):                       # topic 개수
    list = []
    for i in range(11):                   # 분기 개수
        topic_li = ldaseq.print_topic_times(topic =j)[i]
        for topic, prob in topic_li:
            if topic not in list:
                list.append(topic)
    print('topic',j,':',list)
# Out:
# topic 0 : ['인증', '로그인', '계정', '본인인증', '신분증', '주민등록증', '입력', '발급', '아직', '등록', '민증', '비밀번호', '이나', '학생', '선물', '운전면허증', '미성년', '비번', '고요', '문제', '단독']
# topic 1 : ['계정', '탈퇴', '가입', '인증', '로그인', '만원', '전화', '연동', '카드', '서비스', '고객', '해지', '센터', '기존', '번호', '출금', '정보', '연결', '수가', '중인']
# topic 2 : ['결제', '오류', '어플', '송금', '부탁', '설치', '제대로', '불편', '미성년', '수단', '인지', '제하', '드립', '이벤트', '종료', '보고', '먹통', '시스템', '거나', '실행', '제발']
# topic 3 : ['계좌', '주식', '증권', '거래', '불편', '투자', '안보', '펀드', '입금', '금액', '연결', '생각', '혜택', '려면', '이상', '쓰기', '직관', '개선', '사용자', '송금', '보이', '언제']
# topic 4 : ['업데이트', '소리', '투자', '불편', '미니', '금고', '설정', '화면', '부터', '실행', '알림', '이후', '처음', '관리', '시작', '증권', '띠링', '버튼', '갤럭시', '펀드', '정보']
# topic 5 : ['연결', '시간', '접속', '해지', '등록', '점검', '최악', '조회', '오류', '업데이트', '문제', '포인트', '데이터', '고하', '뭔가', '상태', '신청', '오늘', '결제', '최근', '금융', '렉', '짜증']
# topic 6 : ['결제', '카드', '충전', '교통카드', '짜증', '불편', '위젯', '인식', '포인트', '리뷰', '설정', '모바일', '쓰레기', '필요', '해결', '바코드', '삼성', '자동', '수수료', '주문', '금액', '얼굴인식', '전부']

# %%
import pandas as pd
df = pd.DataFrame(columns = range(11), index = range(7))
time_corpus = [154, 140, 199, 157, 123, 84, 117, 90, 75, 112, 106]

start = 0

for idx, cor in enumerate(time_corpus):
    sum_li = np.zeros(7)
    end = start+cor
    for i in range(start,end):
        li = ldaseq.doc_topics(i)
        li = np.array(li)
        sum_li+=li
    df.iloc[:,idx] = sum_li/cor
    print('time:',idx)
    print(start,end)
    print(sum_li/cor)
    print(np.sum(sum_li/cor))
    start+=cor
# Out:
# time: 0
# 0 154
# [0.09266855 0.14271221 0.10324223 0.07723753 0.24806297 0.13305272
#  0.20302378]
# 1.0000000000000004
# time: 1
# 154 294
# [0.16369992 0.17884919 0.12991539 0.10265911 0.19761821 0.09408841
#  0.13316977]
# 1.0000000000000002
# time: 2
# 294 493
# [0.08611638 0.18132823 0.12005734 0.13165656 0.20526441 0.13803432
#  0.13754276]
# 1.0
# time: 3
# 493 650
# [0.17080819 0.13201921 0.10603573 0.19598721 0.15193613 0.08926273
#  0.15395081]
# 1.0000000000000009
# time: 4
# 650 773
# [0.22942463 0.17284736 0.15075667 0.14859029 0.14384744 0.04664895
#  0.10788465]
# 1.0000000000000004
# time: 5
# 773 857
# [0.15354897 0.11723641 0.14282975 0.17411901 0.12651692 0.08836012
#  0.19738881]
# 1.0000000000000002
# time: 6
# 857 974
# [0.23351298 0.12409158 0.11469998 0.20424511 0.11696935 0.10180218
#  0.10467882]
# 0.9999999999999998
# time: 7
# 974 1064
# [0.10645856 0.0864577  0.18148856 0.16875735 0.15760185 0.13758522
#  0.16165076]
# 1.0000000000000004
# time: 8
# 1064 1139
# [0.0910137  0.09331665 0.11331743 0.21638351 0.1597296  0.14014422
#  0.18609489]
# 1.0
# time: 9
# 1139 1251
# [0.11357837 0.07789524 0.12348696 0.13852017 0.18180624 0.17909546
#  0.18561756]
# 1.0000000000000002
# time: 10
# 1251 1357
# [0.11959273 0.12904126 0.19817199 0.22970319 0.05784602 0.13499134
#  0.13065346]
# 0.9999999999999996

# %%
display(df)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.092669    0.1637  0.086116  0.170808  0.229425  0.153549  0.233513
# 1  0.142712  0.178849  0.181328  0.132019  0.172847  0.117236  0.124092
# 2  0.103242  0.129915  0.120057  0.106036  0.150757   0.14283    0.1147
# 3  0.077238  0.102659  0.131657  0.195987   0.14859  0.174119  0.204245
# 4  0.248063  0.197618  0.205264  0.151936  0.143847  0.126517  0.116969
# 5  0.133053  0.094088  0.138034  0.089263  0.046649   0.08836  0.101802
# 6  0.203024   0.13317  0.137543  0.153951  0.107885  0.197389  0.104679
#
#          7         8         9         10
# 0  0.106459  0.091014  0.113578  0.119593
# 1  0.086458  0.093317  0.077895  0.129041
# 2  0.181489  0.113317  0.123487  0.198172
# 3  0.168757  0.216384   0.13852  0.229703
# 4  0.157602   0.15973  0.181806  0.057846
# 5  0.137585  0.140144  0.179095  0.134991
# 6  0.161651  0.186095  0.185618  0.130653

# %%
df = df.apply(pd.to_numeric)
df.columns = ['2021-02~2021-04','2021-05~2021-07','2021-08~2021-10','2021-11~2022-01','2022-02~2022-04','2022-05~2022-07','2022-08~2022-10','2022-11~2023-01',
              '2023-02~2023-04','2023-05~2023-07','2023-08~2023-10']

# %%
df
# Out:
#    2021-02~2021-04  2021-05~2021-07  2021-08~2021-10  2021-11~2022-01  \
# 0         0.092669         0.163700         0.086116         0.170808
# 1         0.142712         0.178849         0.181328         0.132019
# 2         0.103242         0.129915         0.120057         0.106036
# 3         0.077238         0.102659         0.131657         0.195987
# 4         0.248063         0.197618         0.205264         0.151936
# 5         0.133053         0.094088         0.138034         0.089263
# 6         0.203024         0.133170         0.137543         0.153951
#
#    2022-02~2022-04  2022-05~2022-07  2022-08~2022-10  2022-11~2023-01  \
# 0         0.229425         0.153549         0.233513         0.106459
# 1         0.172847         0.117236         0.124092         0.086458
# 2         0.150757         0.142830         0.114700         0.181489
# 3         0.148590         0.174119         0.204245         0.168757
# 4         0.143847         0.126517         0.116969         0.157602
# 5         0.046649         0.088360         0.101802         0.137585
# 6         0.107885         0.197389         0.104679         0.161651
#
#    2023-02~2023-04  2023-05~2023-07  2023-08~2023-10
# 0         0.091014         0.113578         0.119593
# 1         0.093317         0.077895         0.129041
# 2         0.113317         0.123487         0.198172
# 3         0.216384         0.138520         0.229703
# 4         0.159730         0.181806         0.057846
# 5         0.140144         0.179095         0.134991
# 6         0.186095         0.185618         0.130653

# %%
df.to_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/kakao_datafile/kakao_topic_proportation.csv',index=False)

# %%
# Set the font for Korean characters

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = "C:/Users/junbong heo/OneDrive/바탕 화면/NanumGothic.ttf"  # Change the path based on your system
font_prop = fm.FontProperties(fname=font_path, size=15)

plt.figure(figsize=(50,16))
df.T.plot(kind = 'line',style='.-')
plt.title('<<-Topic Proportion->>',fontsize=20)
plt.ylabel('Topic proportion',fontsize=20)
plt.xticks(rotation = 45,fontsize=15)
plt.yticks(fontsize=15)
# Add Korean labels to the legend
legend_labels = ['본인인증', '계정관리', 'UI', '증권', '알림','연결 및 접속','카드 관리 기능']  # Replace with your Korean labels
plt.legend(legend_labels,bbox_to_anchor=(1.9, 1), loc="upper right", ncol=1, fontsize="15", prop=font_prop)

# %%
a0=ldaseq.print_topics(time=0)                    # 21년도 2월 분기
a1=ldaseq.print_topics(time=1)                    # 21년도 5월 분기 
a2=ldaseq.print_topics(time=2)                    # 21년도 8월 분기
a3=ldaseq.print_topics(time=3)                    # 21년도 11월 분기
a4=ldaseq.print_topics(time=4)                    # 22년도 2월 분기 
a5=ldaseq.print_topics(time=5)                    # 22년도 5월 분기
a6=ldaseq.print_topics(time=6)                    # 22년도 8월 분기
a7=ldaseq.print_topics(time=7)                    # 22년도 11월 분기 
a8=ldaseq.print_topics(time=8)                    # 23년도 2월 분기
a9=ldaseq.print_topics(time=9)                    # 23년도 5월 분기
a10=ldaseq.print_topics(time=10)                  # 23년도 8월 분기

# %%
a0
# Out:
# [[('인증', 0.0810228536830724),
#   ('로그인', 0.08080186672498656),
#   ('계정', 0.04405605288212951),
#   ('본인인증', 0.03675183268089688),
#   ('신분증', 0.034970150387088825),
#   ('주민등록증', 0.028879145378000105),
#   ('입력', 0.02856319979540616),
#   ('발급', 0.027732826588387008),
#   ('아직', 0.02676085336278835),
#   ('등록', 0.024684370835145776),
#   ('민증', 0.024023759622446687),
#   ('비밀번호', 0.01555083603022815),
#   ('이나', 0.015128893012190257),
#   ('학생', 0.013342571695082352),
#   ('선물', 0.013318332234947121),
#   ('운전면허증', 0.013192719554333819),
#   ('미성년', 0.01214005976268391),
#   ('비번', 0.011874145817319312),
#   ('고요', 0.011557904989705067),
#   ('문제', 0.011541770280037602)],
#  [('계정', 0.06813554355358843),
#   ('탈퇴', 0.0378785708279945),
#   ('가입', 0.03475239405611031),
#   ('인증', 0.03211281280333966),
#   ('로그인', 0.025341544831744976),
#   ('만원', 0.022951748729186903),
#   ('전화', 0.02294797765947086),
#   ('연동', 0.020115365742213225),
#   ('카드', 0.019647959710389868),
#   ('서비스', 0.019098428267547627),
#   ('고객', 0.018662536679610275),
#   ('해지', 0.018286662252973578),
#   ('센터', 0.018023026679853102),
#   ('기존', 0.016996486767974626),
#   ('번호', 0.016709875922176452),
#   ('출금', 0.01670281490648813),
#   ('정보', 0.015162624559911658),
#   ('연결', 0.0137216355119759),
#   ('수가', 0.013295360279492843),
#   ('중인', 0.011955177381916876)],
#  [('결제', 0.08951443498676037),
#   ('오류', 0.06800869945815119),
#   ('어플', 0.04714466190703358),
#   ('송금', 0.03422916049022062),
#   ('부탁', 0.028429727464845664),
#   ('설치', 0.02711469551391613),
#   ('제대로', 0.018827386375320068),
#   ('불편', 0.016931944299872128),
#   ('미성년', 0.016719017011992063),
#   ('수단', 0.016440260563562223),
#   ('인지', 0.016110537859493634),
#   ('제하', 0.014594546417946448),
#   ('드립', 0.014417750385938488),
#   ('이벤트', 0.013751655502932806),
#   ('종료', 0.013739463041997666),
#   ('보고', 0.013688726844309466),
#   ('먹통', 0.01236782786720988),
#   ('시스템', 0.012077107865469892),
#   ('거나', 0.011853518931590304),
#   ('실행', 0.0116981457544668)],
#  [('계좌', 0.06426747787025167),
#   ('주식', 0.052755466169231165),
#   ('증권', 0.04011542090020601),
#   ('거래', 0.025553723069544038),
#   ('불편', 0.0234882042849923),
#   ('투자', 0.021234986971618026),
#   ('안보', 0.018167674221116183),
#   ('펀드', 0.017886587017129463),
#   ('입금', 0.01766591722938862),
#   ('금액', 0.017566602937121693),
#   ('연결', 0.017136945490925155),
#   ('생각', 0.016253541037983692),
#   ('혜택', 0.015178687580274556),
#   ('려면', 0.012905605070778238),
#   ('이상', 0.012496806267958122),
#   ('쓰기', 0.012245770309867498),
#   ('직관', 0.011355798836166558),
#   ('개선', 0.010795799658515355),
#   ('사용자', 0.010675629166043744),
#   ('송금', 0.010381013477402517)],
#  [('업데이트', 0.09105053429935465),
#   ('소리', 0.07501301121222352),
#   ('투자', 0.04121294518696392),
#   ('불편', 0.035479253688690905),
#   ('미니', 0.02882238217986494),
#   ('금고', 0.02698374899410914),
#   ('설정', 0.02553655339067336),
#   ('화면', 0.025515176904959382),
#   ('부터', 0.024616960579976425),
#   ('실행', 0.024565672828071275),
#   ('알림', 0.0216257321414669),
#   ('이후', 0.021514974470085605),
#   ('처음', 0.019417059060303277),
#   ('관리', 0.017448623641255108),
#   ('시작', 0.016563155180242033),
#   ('증권', 0.015141070756898295),
#   ('띠링', 0.01385246506455186),
#   ('버튼', 0.013465854756970961),
#   ('갤럭시', 0.013028367121544785),
#   ('펀드', 0.012490058392332493)],
#  [('연결', 0.049692227568205107),
#   ('시간', 0.04286328432067707),
#   ('접속', 0.03816690527099471),
#   ('해지', 0.025510071579840463),
#   ('등록', 0.02412955115050962),
#   ('점검', 0.024087019732776847),
#   ('최악', 0.024036584534908503),
#   ('조회', 0.022205384107453544),
#   ('오류', 0.02095401225411837),
#   ('업데이트', 0.018681319604796277),
#   ('문제', 0.018414815058820023),
#   ('포인트', 0.017922673697232334),
#   ('데이터', 0.016287904190447386),
#   ('고하', 0.01604038477753651),
#   ('뭔가', 0.015869197796399163),
#   ('상태', 0.015199402384813113),
#   ('신청', 0.015101987014030151),
#   ('오늘', 0.01474460777196184),
#   ('결제', 0.014732763500518269),
#   ('최근', 0.014503577882753787)],
#  [('결제', 0.05970171832349247),
#   ('카드', 0.04808439241094665),
#   ('충전', 0.044242939843527486),
#   ('교통카드', 0.03918627712351648),
#   ('짜증', 0.025800115405055196),
#   ('불편', 0.02311374014111834),
#   ('위젯', 0.01705954211618605),
#   ('인식', 0.015108809362673094),
#   ('포인트', 0.013812300351747285),
#   ('리뷰', 0.01377928091191745),
#   ('설정', 0.012217407958333936),
#   ('모바일', 0.012004460285814103),
#   ('쓰레기', 0.011335416694203428),
#   ('필요', 0.011134178267385816),
#   ('해결', 0.0110605491337529),
#   ('바코드', 0.009647687568649364),
#   ('삼성', 0.009453695394983207),
#   ('자동', 0.009427532144471363),
#   ('수수료', 0.009072281245136081),
#   ('주문', 0.009040580635903999)]]

# %%
# topic 3 상위 발생확률 5개 단어의 기간별 추이 그래프 그리기

topic3_first=[]
topic3_second=[]
topic3_third=[]
topic3_fourth=[]
topic3_fifth=[]

# a3 (21년도 7월은 빼기)
for nft_date in [a0,a1,a2,a3,a4,a5,a6,a7,a8,a9,a10]:
  for item in nft_date[3]:        # nft_date[3]는 기간별 네 번째 토픽 리스트임
    if item[0]=='주식':
      topic3_first.append(item[1])
    if item[0]=='증권':
      topic3_second.append(item[1])
    if item[0]=='거래':
      topic3_third.append(item[1])
    if item[0]=='투자':
      topic3_fourth.append(item[1])
    if item[0]=='펀드':
      topic3_fifth.append(item[1])

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

nft_period=['2021-02~2021-04','2021-05~2021-07','2021-08~2021-10','2021-11~2022-01','2022-02~2022-04','2022-05~2022-07','2022-08~2022-10','2022-11~2023-01',
              '2023-02~2023-04','2023-05~2023-07','2023-08~2023-10']
plt.figure(figsize=(14,8))
fontpath='C:/Users/junbong heo/OneDrive/바탕 화면/NanumGothic.ttf'
font = fm.FontProperties(fname=fontpath,size=15).get_name()
plt.rc('font', family=font)
plt.plot(nft_period, topic3_first,label='주식', linestyle='--', marker='^' )
plt.plot(nft_period,topic3_second,label='증권', linestyle='--', marker='.' )
plt.plot(nft_period, topic3_third,label='거래',linestyle='--',marker='o')
plt.plot(nft_period,topic3_fourth,label='투자',linestyle='--',marker='<')
plt.plot(nft_period, topic3_fifth,label='펀드',linestyle='--',marker='v')
plt.legend(fontsize=14,ncol=2)
plt.xticks(rotation=45,fontsize=20)
plt.yticks(rotation=45,fontsize=20)
plt.xlabel(' Period ',fontsize=30)
plt.ylabel(' Probability ',fontsize=30)
plt.title('증권',fontsize=40)

#fontpath='C:/Users/junbong heo/OneDrive/바탕 화면/NanumGothic.ttf'
#font = fm.FontProperties(fname=fontpath,size=12).get_name()
#plt.rc('font', family=font)
plt.show()

# %%
# topic 3 상위 발생확률 5개 단어의 기간별 추이 그래프 그리기

topic3_first=[]
topic3_second=[]
topic3_third=[]
topic3_fourth=[]


# a1 (21년도 7월은 빼기)

for nft_date in [a0,a1,a2,a3,a4,a5,a6,a7,a8,a9,a10]:
  for item in nft_date[3]:        # nft_date[1]는 기간별 두번째 토픽 리스트임
    if item[0]=='투자':
      topic3_first.append(item[1])
    if item[0]=='증권':
      topic3_second.append(item[1])
    if item[0]=='펀드':
      topic3_third.append(item[1])
    if item[0]=='주식':
      topic3_fourth.append(item[1])

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

nft_period=['2021-01~03','2021-04~06','2021-07~09','2021-10~12','2022-01~03','2022-04~06','2022-07~09','2022-10~12',
              '2023-01~03','2023-04~06','2023-07~09']
plt.figure(figsize=(14,8))
fontpath='C:/Users/junbong heo/OneDrive/바탕 화면/NanumGothic.ttf'
font = fm.FontProperties(fname=fontpath,size=15).get_name()
plt.rc('font', family=font)
plt.plot(nft_period, topic3_first,label='투자', linestyle='--', marker='^' )
plt.plot(nft_period,topic3_second,label='증권', linestyle='--', marker='.' )
plt.plot(nft_period, topic3_third,label='펀드',linestyle='--',marker='o')
plt.plot(nft_period,topic3_fourth,label='주식',linestyle='--',marker='<')
#plt.plot(nft_period, topic1_fifth,label='신분증',linestyle='--',marker='v')
plt.legend(fontsize=14,ncol=2)
plt.xticks(rotation=45,fontsize=20)
plt.yticks(rotation=45,fontsize=20)
plt.xlabel(' Period ',fontsize=30)
plt.ylabel(' Probability ',fontsize=30)
plt.title('증권',fontsize=40)

#fontpath='C:/Users/junbong heo/OneDrive/바탕 화면/NanumGothic.ttf'
#font = fm.FontProperties(fname=fontpath,size=12).get_name()
#plt.rc('font', family=font)
plt.show()

# %%
# topic 2 상위 발생확률 5개 단어의 기간별 추이 그래프 그리기

topic2_first=[]
topic2_second=[]
topic2_third=[]
topic2_fourth=[]
topic2_fifth=[]

# a6 (21년도 7월은 빼기)
#'충전', '주식', '교통카드', '출금', '거래',
for nft_date in [a0,a1,a2,a3,a4,a5,a6,a7,a8,a9,a10]:
  first_elements=[item[0] for item in nft_date[2]]
  if '결제' not in first_elements:
    topic2_first.append(0)
  if '오류' not in first_elements:
    topic2_second.append(0)
  if '어플' not in first_elements:
    topic2_third.append(0)
  if '송금' not in first_elements:
    topic2_fourth.append(0)
  if '설치' not in first_elements:
    topic2_fifth.append(0)
  for item in nft_date[2]:        # nft_date[2]는 기간별 세 번째 토픽 리스트임
    if item[0]=='결제':
      topic2_first.append(item[1])
    if item[0]=='오류':
      topic2_second.append(item[1])
    if item[0]=='어플':
      topic2_third.append(item[1])
    if item[0]=='송금':
      topic2_fourth.append(item[1])
    if item[0]=='설치':
      topic2_fifth.append(item[1])

# %%
topic2_first
# Out:
# [0.08951443498676037,
#  0.09228053013646126,
#  0.09271513231285257,
#  0.0905356012905024,
#  0.09050009507587466,
#  0.09016161793573355,
#  0.09204570919484735,
#  0.09237466691579924,
#  0.09273864587596738,
#  0.09237479233150901,
#  0.09297406323261458]

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

nft_period=['2021-02~2021-04','2021-05~2021-07','2021-08~2021-10','2021-11~2022-01','2022-02~2022-04','2022-05~2022-07','2022-08~2022-10','2022-11~2023-01',
              '2023-02~2023-04','2023-05~2023-07','2023-08~2023-10']
plt.figure(figsize=(14,8))
fontpath='C:/Users/junbong heo/OneDrive/바탕 화면/NanumGothic.ttf'
font = fm.FontProperties(fname=fontpath,size=15).get_name()
plt.rc('font', family=font)
plt.plot(nft_period, topic2_first,label='결제', linestyle='--', marker='^' )
plt.plot(nft_period,topic2_second,label='오류', linestyle='--', marker='.' )
plt.plot(nft_period, topic2_third,label='어플',linestyle='--',marker='o')
plt.plot(nft_period, topic2_fourth,label='송금',linestyle='--',marker='<')
plt.plot(nft_period, topic2_fifth,label='설치',linestyle='--',marker='>')
plt.legend(fontsize=14,ncol=2)
plt.xticks(rotation=45,fontsize=20)
plt.yticks(rotation=45,fontsize=20)
plt.xlabel(' Period ',fontsize=30)
plt.ylabel(' Probability ',fontsize=30)
plt.title('UI',fontsize=40)

#fontpath='C:/Users/junbong heo/OneDrive/바탕 화면/NanumGothic.ttf'
#font = fm.FontProperties(fname=fontpath,size=12).get_name()
#plt.rc('font', family=font)
plt.show()
