# %%
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Twitter
from konlpy.tag import Okt
from matplotlib import font_manager, rc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import networkx as nx

# %%
df_2019=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/toss_datafile/frequency_data/frequency_y19.csv')
df_2019.head(5)
# Out:
#    word  freqeuncy  year
# 0  업데이트        232  2019
# 1    계좌        196  2019
# 2    송금        187  2019
# 3    불편         83  2019
# 4    오류         75  2019

# %%
g_2019 = nx.karate_club_graph()
g_2019 = nx.from_pandas_edgelist(df_2019, source = 'word', target = 'year')
pos = nx.spring_layout(g_2019, k = 0.1, iterations=200)

color_map_node = []
for node in g_2019:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2019, pos, node_size = 3000, node_color = color_map_node)
nx.draw_networkx_edges(g_2019, pos, width=1)
nx.draw_networkx_labels(g_2019, pos,  font_size=30, font_family='Malgun Gothic')
plt.show()

# %%
df_2020=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/toss_datafile/frequency_data/frequency_y20.csv')
df_2020.head(5)
# Out:
#    word  freqeuncy  year
# 0  업데이트        114  2020
# 1    계좌         94  2020
# 2    카드         68  2020
# 3    어플         47  2020
# 4    연결         46  2020

# %%
g_2020 = nx.karate_club_graph()
g_2020 = nx.from_pandas_edgelist(df_2020, source = 'word', target = 'year')
pos = nx.spring_layout(g_2020, k = 0.1, iterations=200)

color_map_node = []
for node in g_2020:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2020, pos, node_size = 3000, node_color = color_map_node)
nx.draw_networkx_edges(g_2020, pos, width=1)
nx.draw_networkx_labels(g_2020, pos,  font_size=30, font_family='Malgun Gothic')
plt.show()

# %%
df_2021=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/toss_datafile/frequency_data/frequency_y21.csv')
df_2021.head(5)
# Out:
#    word  freqeuncy  year
# 0    계좌        110  2021
# 1  업데이트         97  2021
# 2    주식         63  2021
# 3    어플         57  2021
# 4    카드         50  2021

# %%
g_2021 = nx.karate_club_graph()
g_2021 = nx.from_pandas_edgelist(df_2021, source = 'word', target = 'year')
pos = nx.spring_layout(g_2021, k = 0.1, iterations=200)

color_map_node = []
for node in g_2021:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2021, pos, node_size = 3000, node_color = color_map_node)
nx.draw_networkx_edges(g_2021, pos, width=1)
nx.draw_networkx_labels(g_2021, pos,  font_size=30, font_family='Malgun Gothic')
plt.show()

# %%
df_2022=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/toss_datafile/frequency_data/frequency_y22.csv')
df_2022.head(5)
# Out:
#    word  freqeuncy  year
# 0  업데이트        164  2022
# 1    계좌         86  2022
# 2    불편         68  2022
# 3    연결         58  2022
# 4    주식         42  2022

# %%
g_2022 = nx.karate_club_graph()
g_2022 = nx.from_pandas_edgelist(df_2022, source = 'word', target = 'year')
pos = nx.spring_layout(g_2022, k = 0.1, iterations=200)

color_map_node = []
for node in g_2022:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2022, pos, node_size = 3000, node_color = color_map_node)
nx.draw_networkx_edges(g_2022, pos, width=1)
nx.draw_networkx_labels(g_2022, pos,  font_size=30, font_family='Malgun Gothic')
plt.show()

# %%
df_2023=pd.read_csv('C:/Users/junbong heo/OneDrive/바탕 화면/textmining_project/toss_datafile/frequency_data/frequency_y23.csv')
df_2023.head(5)
# Out:
#    word  freqeuncy  year
# 0    광고        362  2023
# 1  업데이트        307  2023
# 2   포인트        296  2023
# 3    알림        165  2023
# 4    불편        153  2023

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   word       20 non-null     object
#  1   freqeuncy  20 non-null     int64
#  2   year       20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 612.0+ bytes

# %%
g_2023 = nx.karate_club_graph()
g_2023 = nx.from_pandas_edgelist(df_2023, source = 'word', target = 'year')
pos = nx.spring_layout(g_2023, k = 0.1, iterations=200)

color_map_node = []
for node in g_2023:
    color_map_node.append('white')

plt.figure(figsize=(20, 20))

nx.draw_networkx_nodes(g_2023, pos, node_size = 3000, node_color = color_map_node)
nx.draw_networkx_edges(g_2023, pos, width=1)
nx.draw_networkx_labels(g_2023, pos,  font_size=30, font_family='Malgun Gothic')
plt.show()

# %%
whole_data=pd.concat([df_2019,df_2020,df_2021,df_2022,df_2023])
whole_data
# Out:
#     word  freqeuncy  year
# 0   업데이트        232  2019
# 1     계좌        196  2019
# 2     송금        187  2019
# 3     불편         83  2019
# 4     오류         75  2019
# ..   ...        ...   ...
# 15    사람         98  2023
# 16    오류         91  2023
# 17  교통카드         90  2023
# 18    문제         88  2023
# 19    점검         85  2023
#
# [100 rows x 3 columns]

# %%
g = nx.karate_club_graph()
g = nx.from_pandas_edgelist(whole_data, source = 'word', target = 'year')
pos = nx.spring_layout(g, k = 0.1, iterations=200)

color_map_node = []
for node in g:
  if node == 2019:
    color_map_node.append('blue')
  elif node == 2020:
    color_map_node.append('red')
  elif node == 2021:
    color_map_node.append('yellow')
  elif node == 2022:
    color_map_node.append('green')
  elif node == 2023:
    color_map_node.append('orange')
  else:
    color_map_node.append('white')

color_map_edge = []
for edges in g.edges():
    if 2019 in edges:
        color_map_edge.append('blue')
    if 2020 in edges:
        color_map_edge.append('red')
    if 2021 in edges:
        color_map_edge.append('yellow')
    if 2022 in edges:
        color_map_edge.append('green')
    if 2023 in edges:
        color_map_edge.append('orange')

plt.figure(figsize=(30, 30))

nx.draw_networkx_nodes(g, pos, node_size = 5000, node_color = color_map_node)
nx.draw_networkx_edges(g, pos, width=1, edge_color = color_map_edge)
nx.draw_networkx_labels(g, pos,  font_size=30, font_family='Malgun Gothic')

plt.show()

# %%
import networkx as nx
import pandas as pd

df= pd.DataFrame(whole_data)


# 그래프 생성

g= nx.from_pandas_edgelist(df, source='word', target='year')

# Betweenness Centrality 계산
betweenness_centrality = nx.betweenness_centrality(g)

# Betweenness Centrality를 데이터프레임으로 변환
df_centrality = pd.DataFrame(list(betweenness_centrality.items()), columns=['word', 'betweenness_centrality'])

# 결과 출력
print(df_centrality)
# Out:
#     word  betweenness_centrality
# 0   업데이트                0.050026
# 1   2019                0.218822
# 2     계좌                0.050026
# 3     송금                0.003133
# 4     불편                0.050026
# 5     오류                0.050026
# 6     카드                0.050026
# 7     문제                0.015582
# 8     연결                0.022704
# 9     입력                0.010422
# 10   수수료                0.005602
# 11    이체                0.003133
# 12    어플                0.050026
# 13    등록                0.010422
# 14    버전                0.000000
# 15    무료                0.000000
# 16    화면                0.030898
# 17    인증                0.022704
# 18   로그인                0.000000
# 19    조회                0.002104
# 20  비밀번호                0.002104
# 21  2020                0.290720
# 22    친구                0.000000
# 23    로딩                0.000000
# 24    걸음                0.000000
# 25    광고                0.020789
# 26    부터                0.005103
# 27    어도                0.000000
# 28    수가                0.000000
# 29    전화                0.000000
# 30    가입                0.000000
# 31  2021                0.235830
# 32    주식                0.004045
# 33    증권                0.000000
# 34    정보                0.000000
# 35    알림                0.016924
# 36    실행                0.000000
# 37    거래                0.000000
# 38    사람                0.006033
# 39  2022                0.260315
# 40    결제                0.000000
# 41   인증서                0.000000
# 42    금액                0.000000
# 43    마다                0.000000
# 44    이후                0.000000
# 45  2023                0.322324
# 46   포인트                0.000000
# 47    혜택                0.000000
# 48   동영상                0.000000
# 49    충전                0.000000
# 50   데이터                0.000000
# 51   라이브                0.000000
# 52  교통카드                0.000000
# 53    점검                0.000000

# %%
df_centrality.sort_values('betweenness_centrality',ascending=False)
# Out:
#     word  betweenness_centrality
# 45  2023                0.322324
# 21  2020                0.290720
# 39  2022                0.260315
# 31  2021                0.235830
# 1   2019                0.218822
# 12    어플                0.050026
# 0   업데이트                0.050026
# 6     카드                0.050026
# 5     오류                0.050026
# 4     불편                0.050026
# 2     계좌                0.050026
# 16    화면                0.030898
# 8     연결                0.022704
# 17    인증                0.022704
# 25    광고                0.020789
# 35    알림                0.016924
# 7     문제                0.015582
# 13    등록                0.010422
# 9     입력                0.010422
# 38    사람                0.006033
# 10   수수료                0.005602
# 26    부터                0.005103
# 32    주식                0.004045
# 11    이체                0.003133
# 3     송금                0.003133
# 20  비밀번호                0.002104
# 19    조회                0.002104
# 51   라이브                0.000000
# 52  교통카드                0.000000
# 46   포인트                0.000000
# 50   데이터                0.000000
# 44    이후                0.000000
# 47    혜택                0.000000
# 48   동영상                0.000000
# 43    마다                0.000000
# 42    금액                0.000000
# 49    충전                0.000000
# 41   인증서                0.000000
# 40    결제                0.000000
# 27    어도                0.000000
# 37    거래                0.000000
# 36    실행                0.000000
# 34    정보                0.000000
# 33    증권                0.000000
# 30    가입                0.000000
# 29    전화                0.000000
# 28    수가                0.000000
# 24    걸음                0.000000
# 23    로딩                0.000000
# 22    친구                0.000000
# 18   로그인                0.000000
# 15    무료                0.000000
# 14    버전                0.000000
# 53    점검                0.000000
